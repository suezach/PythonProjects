# %% [markdown]
# ## Basic Exploration

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

import datetime
from datetime import timedelta
import calendar

# %%
# Import the dataset

aug_21 = pd.read_csv('/Users/zachariah/Downloads/202108-divvy-tripdata.csv')
sep_21 = pd.read_csv('/Users/zachariah/Downloads/202109-divvy-tripdata.csv')
oct_21 = pd.read_csv('/Users/zachariah/Downloads/202110-divvy-tripdata.csv')
nov_21 = pd.read_csv('/Users/zachariah/Downloads/202111-divvy-tripdata.csv')
dec_21 = pd.read_csv('/Users/zachariah/Downloads/202112-divvy-tripdata.csv')
jan_22 = pd.read_csv('/Users/zachariah/Downloads/202201-divvy-tripdata.csv')
feb_22 = pd.read_csv('/Users/zachariah/Downloads/202202-divvy-tripdata.csv')
mar_22 = pd.read_csv('/Users/zachariah/Downloads/202203-divvy-tripdata.csv')
apr_22 = pd.read_csv('/Users/zachariah/Downloads/202204-divvy-tripdata.csv')
may_22 = pd.read_csv('/Users/zachariah/Downloads/202205-divvy-tripdata.csv')
jun_22 = pd.read_csv('/Users/zachariah/Downloads/202206-divvy-tripdata.csv')
jul_22 = pd.read_csv('/Users/zachariah/Downloads/202207-divvy-tripdata.csv')

# %%
# Look at the size, columns and sample rows for August 2021

# %%
aug_21.shape
# Out:
# (804352, 13)

# %%
aug_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804352 entries, 0 to 804351
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             804352 non-null  object
#  1   rideable_type       804352 non-null  object
#  2   started_at          804352 non-null  object
#  3   ended_at            804352 non-null  object
#  4   start_station_name  715894 non-null  object
#  5   start_station_id    715894 non-null  object
#  6   end_station_name    710237 non-null  object
#  7   end_station_id      710237 non-null  object
#  8   start_lat           804352 non-null  float64
#  9   start_lng           804352 non-null  float64
#  10  end_lat             803646 non-null  float64
#  11  end_lng             803646 non-null  float64
#  12  member_casual       804352 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 79.8+ MB

# %%
aug_21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  99103BB87CC6C1BB  electric_bike  2021-08-10 17:15:49  2021-08-10 17:22:44
# 1  EAFCCCFB0A3FC5A1  electric_bike  2021-08-10 17:23:14  2021-08-10 17:39:24
# 2  9EF4F46C57AD234D  electric_bike  2021-08-21 02:34:23  2021-08-21 02:50:36
# 3  5834D3208BFAF1DA  electric_bike  2021-08-21 06:52:55  2021-08-21 07:08:13
# 4  CD825CB87ED1D096  electric_bike  2021-08-19 11:55:29  2021-08-19 12:04:11
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
# Look at the size, columns and sample rows for September 2021

# %%
sep_21.shape
# Out:
# (756147, 13)

# %%
sep_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756147 entries, 0 to 756146
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             756147 non-null  object
#  1   rideable_type       756147 non-null  object
#  2   started_at          756147 non-null  object
#  3   ended_at            756147 non-null  object
#  4   start_station_name  663034 non-null  object
#  5   start_station_id    663036 non-null  object
#  6   end_station_name    656886 non-null  object
#  7   end_station_id      656886 non-null  object
#  8   start_lat           756147 non-null  float64
#  9   start_lng           756147 non-null  float64
#  10  end_lat             755552 non-null  float64
#  11  end_lng             755552 non-null  float64
#  12  member_casual       756147 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 75.0+ MB

# %%
sep_21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  9DC7B962304CBFD8  electric_bike  2021-09-28 16:07:10  2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike  2021-09-28 14:24:51  2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike  2021-09-28 00:20:16  2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike  2021-09-28 14:51:17  2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike  2021-09-28 09:53:12  2021-09-28 10:03:44
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
# Look at the size, columns and sample rows for October 2021

# %%
oct_21.shape
# Out:
# (631226, 13)

# %%
oct_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631226 entries, 0 to 631225
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             631226 non-null  object
#  1   rideable_type       631226 non-null  object
#  2   started_at          631226 non-null  object
#  3   ended_at            631226 non-null  object
#  4   start_station_name  523016 non-null  object
#  5   start_station_id    523016 non-null  object
#  6   end_station_name    516392 non-null  object
#  7   end_station_id      516392 non-null  object
#  8   start_lat           631226 non-null  float64
#  9   start_lng           631226 non-null  float64
#  10  end_lat             630742 non-null  float64
#  11  end_lng             630742 non-null  float64
#  12  member_casual       631226 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 62.6+ MB

# %%
oct_21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  620BC6107255BF4C  electric_bike  2021-10-22 12:46:42  2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike  2021-10-21 09:12:37  2021-10-21 09:14:14
# 2  26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39  2021-10-16 16:36:26
# 3  362947F0437E1514  electric_bike  2021-10-16 16:17:48  2021-10-16 16:19:03
# 4  BB731DE2F2EC51C5  electric_bike  2021-10-20 23:17:54  2021-10-20 23:26:10
#
#          start_station_name start_station_id end_station_name end_station_id  \
# 0  Kingsbury St & Kinzie St     KA1503000043              NaN            NaN
# 1                       NaN              NaN              NaN            NaN
# 2                       NaN              NaN              NaN            NaN
# 3                       NaN              NaN              NaN            NaN
# 4                       NaN              NaN              NaN            NaN
#
# ...

# %%
# Look at the size, columns and sample rows for November 2021

# %%
nov_21.shape
# Out:
# (359978, 13)

# %%
nov_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  object
#  3   ended_at            359978 non-null  object
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 35.7+ MB

# %%
nov_21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  7C00A93E10556E47  electric_bike  2021-11-27 13:27:38  2021-11-27 13:46:38
# 1  90854840DFD508BA  electric_bike  2021-11-27 13:38:25  2021-11-27 13:56:10
# 2  0A7D10CDD144061C  electric_bike  2021-11-26 22:03:34  2021-11-26 22:05:56
# 3  2F3BE33085BCFF02  electric_bike  2021-11-27 09:56:49  2021-11-27 10:01:50
# 4  D67B4781A19928D4  electric_bike  2021-11-26 19:09:28  2021-11-26 19:30:41
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
# Look at the size, columns and sample rows for december 2021

# %%
dec_21.shape
# Out:
# (247540, 13)

# %%
dec_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247540 entries, 0 to 247539
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             247540 non-null  object
#  1   rideable_type       247540 non-null  object
#  2   started_at          247540 non-null  object
#  3   ended_at            247540 non-null  object
#  4   start_station_name  196477 non-null  object
#  5   start_station_id    196477 non-null  object
#  6   end_station_name    194042 non-null  object
#  7   end_station_id      194042 non-null  object
#  8   start_lat           247540 non-null  float64
#  9   start_lng           247540 non-null  float64
#  10  end_lat             247396 non-null  float64
#  11  end_lng             247396 non-null  float64
#  12  member_casual       247540 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 24.6+ MB

# %%
dec_21.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  46F8167220E4431F  electric_bike  2021-12-07 15:06:07  2021-12-07 15:13:42
# 1  73A77762838B32FD  electric_bike  2021-12-11 03:43:29  2021-12-11 04:10:23
# 2  4CF42452054F59C5  electric_bike  2021-12-15 23:10:28  2021-12-15 23:23:14
# 3  3278BA87BF698339   classic_bike  2021-12-26 16:16:10  2021-12-26 16:30:53
# 4  6FF54232576A3B73  electric_bike  2021-12-30 11:31:05  2021-12-30 11:51:21
#
#              start_station_name start_station_id            end_station_name  \
# 0      Laflin St & Cullerton St            13307         Morgan St & Polk St
# 1         LaSalle Dr & Huron St     KP1705001026  Clarendon Ave & Leland Ave
# 2  Halsted St & North Branch St     KA1504000117        Broadway & Barry Ave
# 3  Halsted St & North Branch St     KA1504000117       LaSalle Dr & Huron St
# 4      Leavitt St & Chicago Ave            18058      Clark St & Drummond Pl
#
# ...

# %%
# Look at the size, columns and sample rows for January 2022

# %%
jan_22.shape
# Out:
# (103770, 13)

# %%
jan_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103770 entries, 0 to 103769
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             103770 non-null  object
#  1   rideable_type       103770 non-null  object
#  2   started_at          103770 non-null  object
#  3   ended_at            103770 non-null  object
#  4   start_station_name  87510 non-null   object
#  5   start_station_id    87510 non-null   object
#  6   end_station_name    85843 non-null   object
#  7   end_station_id      85843 non-null   object
#  8   start_lat           103770 non-null  float64
#  9   start_lng           103770 non-null  float64
#  10  end_lat             103684 non-null  float64
#  11  end_lng             103684 non-null  float64
#  12  member_casual       103770 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 10.3+ MB

# %%
jan_22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47  2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike  2022-01-10 08:41:56  2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40  2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike  2022-01-04 00:18:04  2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10  2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# ...

# %%
# Look at the size, columns and sample rows for february 2022

# %%
feb_22.shape
# Out:
# (115609, 13)

# %%
feb_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115609 entries, 0 to 115608
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             115609 non-null  object
#  1   rideable_type       115609 non-null  object
#  2   started_at          115609 non-null  object
#  3   ended_at            115609 non-null  object
#  4   start_station_name  97029 non-null   object
#  5   start_station_id    97029 non-null   object
#  6   end_station_name    95254 non-null   object
#  7   end_station_id      95254 non-null   object
#  8   start_lat           115609 non-null  float64
#  9   start_lng           115609 non-null  float64
#  10  end_lat             115532 non-null  float64
#  11  end_lng             115532 non-null  float64
#  12  member_casual       115609 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 11.5+ MB

# %%
feb_22.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E1E065E7ED285C02  classic_bike  2022-02-19 18:08:41  2022-02-19 18:23:56
# 1  1602DCDC5B30FFE3  classic_bike  2022-02-20 17:41:30  2022-02-20 17:45:56
# 2  BE7DD2AF4B55C4AF  classic_bike  2022-02-25 18:55:56  2022-02-25 19:09:34
# 3  A1789BDF844412BE  classic_bike  2022-02-14 11:57:03  2022-02-14 12:04:00
# 4  07DE78092C62F7B3  classic_bike  2022-02-16 05:36:06  2022-02-16 05:39:00
#
#              start_station_name start_station_id  \
# 0        State St & Randolph St     TA1305000029
# 1   Halsted St & Wrightwood Ave     TA1309000061
# 2        State St & Randolph St     TA1305000029
# 3  Southport Ave & Waveland Ave            13235
# 4        State St & Randolph St     TA1305000029
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0          Clark St & Lincoln Ave          13179  41.884621 -87.627834
# ...

# %%
# Look at the size, columns and sample rows for March 2022

# %%
mar_22.shape
# Out:
# (284042, 13)

# %%
mar_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284042 entries, 0 to 284041
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             284042 non-null  object
#  1   rideable_type       284042 non-null  object
#  2   started_at          284042 non-null  object
#  3   ended_at            284042 non-null  object
#  4   start_station_name  236796 non-null  object
#  5   start_station_id    236796 non-null  object
#  6   end_station_name    232885 non-null  object
#  7   end_station_id      232885 non-null  object
#  8   start_lat           284042 non-null  float64
#  9   start_lng           284042 non-null  float64
#  10  end_lat             283776 non-null  float64
#  11  end_lng             283776 non-null  float64
#  12  member_casual       284042 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 28.2+ MB

# %%
mar_22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  47EC0A7F82E65D52   classic_bike  2022-03-21 13:45:01  2022-03-21 13:51:18
# 1  8494861979B0F477  electric_bike  2022-03-16 09:37:16  2022-03-16 09:43:34
# 2  EFE527AF80B66109   classic_bike  2022-03-23 19:52:02  2022-03-23 19:54:48
# 3  9F446FD9DEE3F389   classic_bike  2022-03-01 19:12:26  2022-03-01 19:22:14
# 4  431128AD9AFFEDC0   classic_bike  2022-03-21 18:37:01  2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %%
# Look at the size, columns and sample rows for April 2022

# %%
apr_22.shape
# Out:
# (371249, 13)

# %%
apr_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371249 entries, 0 to 371248
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             371249 non-null  object
#  1   rideable_type       371249 non-null  object
#  2   started_at          371249 non-null  object
#  3   ended_at            371249 non-null  object
#  4   start_station_name  300362 non-null  object
#  5   start_station_id    300362 non-null  object
#  6   end_station_name    295961 non-null  object
#  7   end_station_id      295961 non-null  object
#  8   start_lat           371249 non-null  float64
#  9   start_lng           371249 non-null  float64
#  10  end_lat             370932 non-null  float64
#  11  end_lng             370932 non-null  float64
#  12  member_casual       371249 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 36.8+ MB

# %%
apr_22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3564070EEFD12711  electric_bike  2022-04-06 17:42:48  2022-04-06 17:54:36
# 1  0B820C7FCF22F489   classic_bike  2022-04-24 19:23:07  2022-04-24 19:43:17
# 2  89EEEE32293F07FF   classic_bike  2022-04-20 19:29:08  2022-04-20 19:35:16
# 3  84D4751AEB31888D   classic_bike  2022-04-22 21:14:06  2022-04-22 21:23:29
# 4  5664BCF0D1DE7A8B  electric_bike  2022-04-16 15:56:30  2022-04-16 16:02:11
#
#           start_station_name start_station_id          end_station_name  \
# 0     Paulina St & Howard St              515   University Library (NU)
# 1  Wentworth Ave & Cermak Rd            13075     Green St & Madison St
# 2       Halsted St & Polk St     TA1307000121     Green St & Madison St
# 3  Wentworth Ave & Cermak Rd            13075  Delano Ct & Roosevelt Rd
# 4       Halsted St & Polk St     TA1307000121   Clinton St & Madison St
#
# ...

# %%
# Look at the size, columns and sample rows for May 2022

# %%
may_22.shape
# Out:
# (634858, 13)

# %%
may_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634858 entries, 0 to 634857
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             634858 non-null  object
#  1   rideable_type       634858 non-null  object
#  2   started_at          634858 non-null  object
#  3   ended_at            634858 non-null  object
#  4   start_station_name  548154 non-null  object
#  5   start_station_id    548154 non-null  object
#  6   end_station_name    541687 non-null  object
#  7   end_station_id      541687 non-null  object
#  8   start_lat           634858 non-null  float64
#  9   start_lng           634858 non-null  float64
#  10  end_lat             634136 non-null  float64
#  11  end_lng             634136 non-null  float64
#  12  member_casual       634858 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 63.0+ MB

# %%
may_22.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  EC2DE40644C6B0F4  classic_bike  2022-05-23 23:06:58  2022-05-23 23:40:19
# 1  1C31AD03897EE385  classic_bike  2022-05-11 08:53:28  2022-05-11 09:31:22
# 2  1542FBEC830415CF  classic_bike  2022-05-26 18:36:28  2022-05-26 18:58:18
# 3  6FF59852924528F8  classic_bike  2022-05-10 07:30:07  2022-05-10 07:38:49
# 4  483C52CAAE12E3AC  classic_bike  2022-05-10 17:31:56  2022-05-10 17:36:57
#
#                   start_station_name start_station_id  \
# 0             Wabash Ave & Grand Ave     TA1307000117
# 1  DuSable Lake Shore Dr & Monroe St            13300
# 2            Clinton St & Madison St     TA1305000032
# 3            Clinton St & Madison St     TA1305000032
# 4            Clinton St & Madison St     TA1305000032
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0       Halsted St & Roscoe St   TA1309000025  41.891466 -87.626761
# ...

# %%
# Look at the size, columns and sample rows for june 2022

# %%
jun_22.shape
# Out:
# (769204, 13)

# %%
jun_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769204 entries, 0 to 769203
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             769204 non-null  object
#  1   rideable_type       769204 non-null  object
#  2   started_at          769204 non-null  object
#  3   ended_at            769204 non-null  object
#  4   start_station_name  676260 non-null  object
#  5   start_station_id    676260 non-null  object
#  6   end_station_name    669052 non-null  object
#  7   end_station_id      669052 non-null  object
#  8   start_lat           769204 non-null  float64
#  9   start_lng           769204 non-null  float64
#  10  end_lat             768149 non-null  float64
#  11  end_lng             768149 non-null  float64
#  12  member_casual       769204 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 76.3+ MB

# %%
jun_22.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  600CFD130D0FD2A4  electric_bike  2022-06-30 17:27:53  2022-06-30 17:35:15
# 1  F5E6B5C1682C6464  electric_bike  2022-06-30 18:39:52  2022-06-30 18:47:28
# 2  B6EB6D27BAD771D2  electric_bike  2022-06-30 11:49:25  2022-06-30 12:02:54
# 3  C9C320375DE1D5C6  electric_bike  2022-06-30 11:15:25  2022-06-30 11:19:43
# 4  56C055851023BE98  electric_bike  2022-06-29 23:36:50  2022-06-29 23:45:17
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
# Look at the size, columns and sample rows for July 2022

# %%
jul_22.shape
# Out:
# (823488, 13)

# %%
jul_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823488 entries, 0 to 823487
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             823488 non-null  object
#  1   rideable_type       823488 non-null  object
#  2   started_at          823488 non-null  object
#  3   ended_at            823488 non-null  object
#  4   start_station_name  711457 non-null  object
#  5   start_station_id    711457 non-null  object
#  6   end_station_name    702537 non-null  object
#  7   end_station_id      702537 non-null  object
#  8   start_lat           823488 non-null  float64
#  9   start_lng           823488 non-null  float64
#  10  end_lat             822541 non-null  float64
#  11  end_lng             822541 non-null  float64
#  12  member_casual       823488 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 81.7+ MB

# %%
jul_22.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  954144C2F67B1932  classic_bike  2022-07-05 08:12:47  2022-07-05 08:24:32
# 1  292E027607D218B6  classic_bike  2022-07-26 12:53:38  2022-07-26 12:55:31
# 2  57765852588AD6E0  classic_bike  2022-07-03 13:58:49  2022-07-03 14:06:32
# 3  B5B6BE44314590E6  classic_bike  2022-07-31 17:44:21  2022-07-31 18:42:50
# 4  A4C331F2A00E79E0  classic_bike  2022-07-13 19:49:06  2022-07-13 20:15:24
#
#            start_station_name start_station_id  \
# 0  Ashland Ave & Blackhawk St            13224
# 1  Buckingham Fountain (Temp)            15541
# 2  Buckingham Fountain (Temp)            15541
# 3  Buckingham Fountain (Temp)            15541
# 4      Wabash Ave & Grand Ave     TA1307000117
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0        Kingsbury St & Kinzie St   KA1503000043  41.907066 -87.667252
# 1           Michigan Ave & 8th St            623  41.869621 -87.623981
# ...

# %% [markdown]
# ### combine the data sets into winter, spring, summer and fall
# #### winter: dec 21, jan 22, feb 22
# #### spring: mar 22, apr 22, may 22
# #### summer: jun 22, july22, aug 21
# #### fall : sep 21, oct 21, nov 21

# %%
# Combine the dataframes dec_21, jan_22, feb_22 into one dataframe winter_df

# %%
winter_df = pd.concat([dec_21, jan_22, feb_22])

# %%
winter_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  46F8167220E4431F  electric_bike  2021-12-07 15:06:07  2021-12-07 15:13:42
# 1  73A77762838B32FD  electric_bike  2021-12-11 03:43:29  2021-12-11 04:10:23
# 2  4CF42452054F59C5  electric_bike  2021-12-15 23:10:28  2021-12-15 23:23:14
# 3  3278BA87BF698339   classic_bike  2021-12-26 16:16:10  2021-12-26 16:30:53
# 4  6FF54232576A3B73  electric_bike  2021-12-30 11:31:05  2021-12-30 11:51:21
#
#              start_station_name start_station_id            end_station_name  \
# 0      Laflin St & Cullerton St            13307         Morgan St & Polk St
# 1         LaSalle Dr & Huron St     KP1705001026  Clarendon Ave & Leland Ave
# 2  Halsted St & North Branch St     KA1504000117        Broadway & Barry Ave
# 3  Halsted St & North Branch St     KA1504000117       LaSalle Dr & Huron St
# 4      Leavitt St & Chicago Ave            18058      Clark St & Drummond Pl
#
# ...

# %%
# Combine the dataframes mar_22, apr_22, may_22 into one dataframe spring_df

# %%
spring_df = pd.concat([mar_22,apr_22,may_22])

# %%
spring_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       47EC0A7F82E65D52   classic_bike  2022-03-21 13:45:01
# 1       8494861979B0F477  electric_bike  2022-03-16 09:37:16
# 2       EFE527AF80B66109   classic_bike  2022-03-23 19:52:02
# 3       9F446FD9DEE3F389   classic_bike  2022-03-01 19:12:26
# 4       431128AD9AFFEDC0   classic_bike  2022-03-21 18:37:01
# ...                  ...            ...                  ...
# 634853  8891BA0053ECEC4F  electric_bike  2022-05-27 22:00:02
# 634854  47D8B5FBCADECFC1  electric_bike  2022-05-15 16:05:39
# 634855  AA8D16CF38B40703  electric_bike  2022-05-21 10:10:13
# 634856  897EBFD44F329E0A  electric_bike  2022-05-12 07:53:58
# 634857  AAC23AB89E8A7733  electric_bike  2022-05-11 21:14:28
#
#                    ended_at                  start_station_name  \
# 0       2022-03-21 13:51:18              Wabash Ave & Wacker Pl
# 1       2022-03-16 09:43:34               Michigan Ave & Oak St
# ...

# %%
# Combine the dataframes jun_22, jul_22, aug_21 into one dataframe summer_df

# %%
summer_df = pd.concat([jun_22, jul_22, aug_21])

# %%
# Combine the dataframes sep_22, oct_22, nov_22 into one dataframe fall_df

# %%
fall_df = pd.concat([sep_21, oct_21, nov_21])

# %% [markdown]
# ### Data Cleaning and Manipulation

# %% [markdown]
# ### In order to clean data effectively, we create two new columns ride_length and day of week

# %%
# Convert the 'object' datatype for columns started_at and ended_at to 'datetime' datatype

spring_df['started_at'] = pd.to_datetime(spring_df['started_at'])
spring_df['ended_at'] = pd.to_datetime(spring_df['ended_at'])

# %%
# Get the ride_length as the difference between the 'ended at' and 'started at' 
spring_df['ride_length'] = spring_df['ended_at'] - spring_df['started_at']

# %%
# To get the day of the week from the 'ended at' column ( 0- monday...)

spring_df['day_of_week'] = spring_df['ended_at'].dt.strftime('%A')

# %%
spring_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  47EC0A7F82E65D52   classic_bike 2022-03-21 13:45:01 2022-03-21 13:51:18
# 1  8494861979B0F477  electric_bike 2022-03-16 09:37:16 2022-03-16 09:43:34
# 2  EFE527AF80B66109   classic_bike 2022-03-23 19:52:02 2022-03-23 19:54:48
# 3  9F446FD9DEE3F389   classic_bike 2022-03-01 19:12:26 2022-03-01 19:22:14
# 4  431128AD9AFFEDC0   classic_bike 2022-03-21 18:37:01 2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %%
# Convert the 'object' datatype for columns started_at and ended_at to 'datetime' datatype

summer_df['started_at'] = pd.to_datetime(summer_df['started_at'])
summer_df['ended_at'] = pd.to_datetime(summer_df['ended_at'])

# %%
# Get the ride_length as the difference between the 'ended at' and 'started at' 
summer_df['ride_length'] = summer_df['ended_at'] - summer_df['started_at']

# %%
# To get the day of the week from the 'ended at' column ( 0- monday...)
summer_df['day_of_week'] = summer_df['ended_at'].dt.strftime('%A')

# %%
summer_df.dtypes
# Out:
# ride_id                        object
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id               object
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# ride_length           timedelta64[ns]
# day_of_week                    object
# dtype: object

# %%
summer_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  600CFD130D0FD2A4  electric_bike 2022-06-30 17:27:53 2022-06-30 17:35:15
# 1  F5E6B5C1682C6464  electric_bike 2022-06-30 18:39:52 2022-06-30 18:47:28
# 2  B6EB6D27BAD771D2  electric_bike 2022-06-30 11:49:25 2022-06-30 12:02:54
# 3  C9C320375DE1D5C6  electric_bike 2022-06-30 11:15:25 2022-06-30 11:19:43
# 4  56C055851023BE98  electric_bike 2022-06-29 23:36:50 2022-06-29 23:45:17
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual ride_length  \
# ...

# %%
# Convert the 'object' datatype for columns started_at and ended_at to 'datetime' datatype

fall_df['started_at'] = pd.to_datetime(fall_df['started_at'])
fall_df['ended_at'] = pd.to_datetime(fall_df['ended_at'])

# %%
# Get the ride_length as the difference between the 'ended at' and 'started at' 
fall_df['ride_length'] = fall_df['ended_at'] - fall_df['started_at']
#fall_df.Timedelta(fall_df.offsets.Second(2))

# %%
# To get the day of the week from the 'ended at' column ( 0- monday...)

fall_df['day_of_week'] = fall_df['ended_at'].dt.strftime('%A')

# %%
fall_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  9DC7B962304CBFD8  electric_bike 2021-09-28 16:07:10 2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike 2021-09-28 14:24:51 2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike 2021-09-28 00:20:16 2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike 2021-09-28 14:51:17 2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike 2021-09-28 09:53:12 2021-09-28 10:03:44
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual ride_length  \
# ...

# %%
# Convert the 'object' datatype for columns started_at and ended_at to 'datetime' datatype

winter_df['started_at'] = pd.to_datetime(winter_df['started_at'])
winter_df['ended_at'] = pd.to_datetime(winter_df['ended_at'])

# %%
# Get the ride_length as the difference between the 'ended at' and 'started at' 
winter_df['ride_length'] = winter_df['ended_at'] - winter_df['started_at']

# %%
# To get the day of the week from the 'ended at' column ( 0- monday...)

winter_df['day_of_week'] = winter_df['ended_at'].dt.strftime('%A')

# %%
winter_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  46F8167220E4431F  electric_bike 2021-12-07 15:06:07 2021-12-07 15:13:42
# 1  73A77762838B32FD  electric_bike 2021-12-11 03:43:29 2021-12-11 04:10:23
# 2  4CF42452054F59C5  electric_bike 2021-12-15 23:10:28 2021-12-15 23:23:14
# 3  3278BA87BF698339   classic_bike 2021-12-26 16:16:10 2021-12-26 16:30:53
# 4  6FF54232576A3B73  electric_bike 2021-12-30 11:31:05 2021-12-30 11:51:21
#
#              start_station_name start_station_id            end_station_name  \
# 0      Laflin St & Cullerton St            13307         Morgan St & Polk St
# 1         LaSalle Dr & Huron St     KP1705001026  Clarendon Ave & Leland Ave
# 2  Halsted St & North Branch St     KA1504000117        Broadway & Barry Ave
# 3  Halsted St & North Branch St     KA1504000117       LaSalle Dr & Huron St
# 4      Leavitt St & Chicago Ave            18058      Clark St & Drummond Pl
#
# ...

# %%
# find out count of negative values for ride length in spring

# %%
neg_spring = spring_df[spring_df['ended_at'] <= spring_df['started_at']]

len(neg_spring)
# Out:
# 97

# %%
pd.set_option('display.max_rows', None)

# %%
# find out count of negative values for ride length in spring

# %%
neg_summer = summer_df[summer_df['ended_at'] <= summer_df['started_at']]

len(neg_summer)
# Out:
# 245

# %%
# find out count of negative values for ride length in fall

# %%
neg_fall = fall_df[fall_df['ended_at'] <= fall_df['started_at']]

len(neg_fall)
# Out:
# 263

# %%
# find out count of negative values for ride length in winter

# %%
neg_winter = winter_df[winter_df['ended_at'] <= winter_df['started_at']]

len(neg_winter)
# Out:
# 31

# %%
# since having negative or zero ride lengths don't contribute to the analysis, we will drop those rows.

# %%
spring_df.drop(spring_df[spring_df['ended_at'] <= spring_df['started_at']].index, inplace = True)

# %%
summer_df.drop(summer_df[summer_df['ended_at'] <= summer_df['started_at']].index, inplace = True)

# %%
fall_df.drop(fall_df[fall_df['ended_at'] <= fall_df['started_at']].index, inplace = True)

# %%
winter_df.drop(winter_df[winter_df['ended_at'] <= winter_df['started_at']].index, inplace = True)

# %%
# statistical summary of ride lengths for spring, summer, fall, winter

# %%
spring_df['ride_length'].describe()
# Out:
# count                   1289908
# mean     0 days 00:19:31.856507
# std      0 days 02:15:29.271059
# min             0 days 00:00:01
# 25%             0 days 00:05:46
# 50%             0 days 00:10:27
# 75%             0 days 00:19:22
# max            25 days 04:17:48
# Name: ride_length, dtype: object

# %%
summer_df['ride_length'].describe()
# Out:
# count                   2396317
# mean     0 days 00:21:53.441840
# std      0 days 02:47:33.888364
# min             0 days 00:00:01
# 25%             0 days 00:06:53
# 50%             0 days 00:12:07
# 75%             0 days 00:21:33
# max            28 days 21:49:10
# Name: ride_length, dtype: object

# %%
fall_df['ride_length'].describe()
# Out:
# count                   1746741
# mean     0 days 00:18:49.746516
# std      0 days 02:12:46.264692
# min             0 days 00:00:01
# 25%             0 days 00:06:04
# 50%             0 days 00:10:40
# 75%             0 days 00:19:12
# max            28 days 06:25:01
# Name: ride_length, dtype: object

# %%
winter_df['ride_length'].describe()
# Out:
# count                    466860
# mean     0 days 00:14:37.157353
# std      0 days 02:06:24.441336
# min             0 days 00:00:01
# 25%             0 days 00:04:54
# 50%             0 days 00:08:12
# 75%             0 days 00:14:16
# max            21 days 02:40:33
# Name: ride_length, dtype: object

# %% [markdown]
# #### Next in order to aid our analysis, create 'time of day' column.
# ##### The time of day columns have 4 custom time frames:
#
# “AM” - 4:00AM-9:59AM
#
# “MID” - 10:00AM-2:59PM
#
# “PM” - 3:00PM-7:59PM
#
# “LATE” - 8:00PM-3:59AM
#
# DISCLAIMER: These time periods were created to correspond to easily categorized periods of the day, strongly influenced by the M-F work schedule. Analysis will be impacted by this choice. In a professional setting, stakeholders would be involved in this decision.

# %%
## First we need to create two new columns "start_hour" & "start_minute" 

spring_df['start_hour'] = spring_df['started_at'].dt.hour
spring_df['start_minute'] = spring_df['started_at'].dt.minute

# %%
summer_df['start_hour'] = summer_df['started_at'].dt.hour
summer_df['start_minute'] = summer_df['started_at'].dt.minute
fall_df['start_hour'] = fall_df['started_at'].dt.hour
fall_df['start_minute'] = fall_df['started_at'].dt.minute
winter_df['start_hour'] = winter_df['started_at'].dt.hour
winter_df['start_minute'] = winter_df['started_at'].dt.minute

# %%
spring_df['time_of_day'] = np.where((spring_df['start_hour'] >= 20) & (spring_df['start_minute'] >= 0), 'Late',
                           np.where((spring_df['start_hour'] <=3) & (spring_df['start_minute'] <= 59 ), 'Late',
                           np.where(((spring_df['start_hour'] >= 4) & (spring_df['start_minute'] >= 0)) & ((spring_df['start_hour'] <= 9) & (spring_df['start_minute'] <= 59)), 'AM',
                           np.where(((spring_df['start_hour'] >= 10) & (spring_df['start_minute'] >= 0))& ((spring_df['start_hour'] <= 14) & (spring_df['start_minute'] <= 59)), 'MID', 'PM'))))

# %%
summer_df['time_of_day'] = np.where((summer_df['start_hour'] >= 20) & (summer_df['start_minute'] >= 0), 'Late',
                           np.where((summer_df['start_hour'] <=3) & (summer_df['start_minute'] <= 59 ), 'Late',
                           np.where(((summer_df['start_hour'] >= 4) & (summer_df['start_minute'] >= 0)) & ((summer_df['start_hour'] <= 9) & (summer_df['start_minute'] <= 59)), 'AM',
                           np.where(((summer_df['start_hour'] >= 10) & (summer_df['start_minute'] >= 0))& ((summer_df['start_hour'] <= 14) & (summer_df['start_minute'] <= 59)), 'MID', 'PM'))))

# %%
fall_df['time_of_day'] = np.where((fall_df['start_hour'] >= 20) & (fall_df['start_minute'] >= 0), 'Late',
                           np.where((fall_df['start_hour'] <=3) & (fall_df['start_minute'] <= 59 ), 'Late',
                           np.where(((fall_df['start_hour'] >= 4) & (fall_df['start_minute'] >= 0)) & ((fall_df['start_hour'] <= 9) & (fall_df['start_minute'] <= 59)), 'AM',
                           np.where(((fall_df['start_hour'] >= 10) & (fall_df['start_minute'] >= 0))& ((fall_df['start_hour'] <= 14) & (fall_df['start_minute'] <= 59)), 'MID', 'PM'))))

# %%
winter_df['time_of_day'] = np.where((winter_df['start_hour'] >= 20) & (winter_df['start_minute'] >= 0), 'Late',
                           np.where((winter_df['start_hour'] <=3) & (winter_df['start_minute'] <= 59 ), 'Late',
                           np.where(((winter_df['start_hour'] >= 4) & (winter_df['start_minute'] >= 0)) & ((winter_df['start_hour'] <= 9) & (winter_df['start_minute'] <= 59)), 'AM',
                           np.where(((winter_df['start_hour'] >= 10) & (winter_df['start_minute'] >= 0))& ((winter_df['start_hour'] <= 14) & (winter_df['start_minute'] <= 59)), 'MID', 'PM'))))

# %%
## Let's rename the values within our rideable_type column
spring_df['rideable_type'] = spring_df['rideable_type'].replace({'classic_bike' : 'Classic', 'docked_bike' : 'Docked', 'electric_bike': 'Electric'})
summer_df['rideable_type'] = summer_df['rideable_type'].replace({'classic_bike' : 'Classic', 'docked_bike' : 'Docked', 'electric_bike': 'Electric'})
fall_df['rideable_type'] = fall_df['rideable_type'].replace({'classic_bike' : 'Classic', 'docked_bike' : 'Docked', 'electric_bike': 'Electric'})
winter_df['rideable_type'] = winter_df['rideable_type'].replace({'classic_bike' : 'Classic', 'docked_bike' : 'Docked', 'electric_bike': 'Electric'})

# %% [markdown]
# ## ANALYSIS to understand the behavior of Casual riders, and how they differ from Member riders

# %% [markdown]
# The variables we will be working with:
#
# Day of week (Monday-Sunday)
#
# Time of day (AM, MID, PM, LATE)
#
# Ride length (in minutes)
#
# User type (member or casual)
#
# Timezone ( 0-15min, 15-30min, 30-45min, +45min)
#
# Seasons (spring, summer, fall, winter)

# %% [markdown]
# ### Spring Season: March, April, May

# %%
# Get the english name from the started_at column
spring_df['month'] = spring_df['started_at'].dt.month_name()
spring_df.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  47EC0A7F82E65D52       Classic 2022-03-21 13:45:01 2022-03-21 13:51:18
# 1  8494861979B0F477      Electric 2022-03-16 09:37:16 2022-03-16 09:43:34
# 2  EFE527AF80B66109       Classic 2022-03-23 19:52:02 2022-03-23 19:54:48
# 3  9F446FD9DEE3F389       Classic 2022-03-01 19:12:26 2022-03-01 19:22:14
# 4  431128AD9AFFEDC0       Classic 2022-03-21 18:37:01 2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %% [markdown]
# ###  FINDING THE MEAN AND MEDIAN RIDE LENGTH FOR SPRING SEASON
#     1. MONTHS
#     2. TIME OF DAY
#     3. DAYS OF WEEK

# %% [markdown]
# ### 1. Analysis of MEAN AND MEDIAN RIDE LENGTH for casual and member riders in  Spring: MONTHS

# %% [markdown]
#  Find the mean ride length for casual and member riders:

# %%
# Table showing the Average ride length for both member and casual riders spring months: April, May, June

s_mean_df = spring_df.groupby(['member_casual','month'], as_index = False)['ride_length'].mean(numeric_only=False)
s_mean_df
# Out:
#   member_casual  month     ride_length
# 0        casual  April 00:29:32.227767
# 1        casual  March 00:32:37.677821
# 2        casual    May 00:30:52.416241
# 3        member  April 00:11:29.578876
# 4        member  March 00:11:57.554319
# 5        member    May 00:13:22.051722

# %%
# Table showing the Median ride length for both member and casual riders spring months: March, April, May

s_median_df = spring_df.groupby(['member_casual','month'], as_index = False)['ride_length'].median(numeric_only=False)

# %%
s_median_df
# Out:
#   member_casual  month ride_length
# 0        casual  April    00:13:50
# 1        casual  March    00:14:13
# 2        casual    May    00:15:17
# 3        member  April    00:07:53
# 4        member  March    00:08:02
# 5        member    May    00:09:23

# %%
# to get the "total minutes":
s_mean_df['mean_ride_minutes'] = s_mean_df['ride_length'].dt.total_seconds()/60
s_mean_df['mean_ride_minutes']
# Out:
# 0    29.537129
# 1    32.627964
# 2    30.873604
# 3    11.492981
# 4    11.959239
# 5    13.367529
# Name: mean_ride_minutes, dtype: float64

# %%
# to get the "total minutes":
s_median_df['mean_ride_minutes'] = s_median_df['ride_length'].dt.total_seconds()/60
s_median_df['mean_ride_minutes']
# Out:
# 0    13.833333
# 1    14.216667
# 2    15.283333
# 3     7.883333
# 4     8.033333
# 5     9.383333
# Name: mean_ride_minutes, dtype: float64

# %% [markdown]
# Plot the comparison of Mean and median for ride lengths in spring months: April, May, June

# %%
fig, axes = plt.subplots(2,2,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Comparison of Median and Mean for the ride lengths for spring season', fontsize = 25)

# set titles
axes[0,0].set_title('MEAN RIDE LENGTH', fontsize = 18)
axes[0,1].set_title('MEDIAN RIDE LENGTH', fontsize = 18)

sns.barplot(ax=axes[0, 0], x='month', y = 'mean_ride_minutes', hue = 'member_casual', data = s_mean_df)
sns.barplot(ax=axes[0, 1], x='month', y = 'mean_ride_minutes', hue = 'member_casual', data = s_median_df)

# Delete the subplot [1,0] and [1,1] that are not needed
fig.delaxes(axes[1,0]) #The indexing is zero-based here
fig.delaxes(axes[1,1]) #The indexing is zero-based here

# %% [markdown]
# ### Observation
# SPRING SEASON:
#
# Mean ride length:
# The mean ride length for member rides is fairly consistent through the spring season(march, april, may).
#
# The difference between casual rider length and member rider length is extremely high.
#
# Median ride length:
# But looking at the median, we observe that the difference between casual ride length is about less than half more than member ride length.
#
# We also observe that member ride length are less than casual ride length throughout all the spring season.

# %% [markdown]
# ### 2. Analysis of MEAN AND MEDIAN RIDE LENGTHS for casual and member riders in all spring: TIME OF DAY

# %%
#Find the mean and median ride lengths for casual and member riders:

# Table showing the Average ride length for both member and casual riders for the time of day

spring_mean =spring_df.groupby(['member_casual','month','time_of_day'], as_index = False)['ride_length'].mean(numeric_only=False)

# Table showing the Median ride length for both member and casual riders for the time of day

spring_median = spring_df.groupby(['member_casual','month','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)

# to get the "total minutes":
spring_mean['mean_ride_minutes'] = spring_mean['ride_length'].dt.total_seconds()/60
spring_median['median_ride_minutes'] = spring_median['ride_length'].dt.total_seconds()/60

### plot the comparison of mean and median ride lengths for time of day in spring months.

fig, axes = plt.subplots(2,2,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Comparison of Median and Mean for the ride lengths for spring season', fontsize = 25)

# set titles
axes[0,0].set_title('MEAN RIDE LENGTH', fontsize = 18)
axes[0,1].set_title('MEDIAN RIDE LENGTH', fontsize = 18)

sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = spring_mean)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = spring_median)

# Delete the subplot [1,0] and [1,1] that are not needed
fig.delaxes(axes[1,0]) #The indexing is zero-based here
fig.delaxes(axes[1,1]) #The indexing is zero-based here

# %% [markdown]
# ### 3. Analysis of MEAN AND MEDIAN RIDE LENGTH for casual and member riders in Spring: DAYS OF WEEK

# %%
#Find the mean and median casual and member riders for days of the week in spring.

# Table showing the Average ride length for both member and casual riders spring months: April, May, June

s_meanday_df = spring_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].mean(numeric_only=False)
s_meanday_df

# Table showing the Median ride length for both member and casual riders spring months: April, May, June

s_medianday_df = spring_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)
s_medianday_df

# to get the "total minutes":
s_meanday_df['mean_ride_minutes'] = s_meanday_df['ride_length'].dt.total_seconds()/60

s_medianday_df['median_ride_minutes'] = s_medianday_df['ride_length'].dt.total_seconds()/60


### Comparison plot of Mean and Median rid lengths for spring season: DAYS OF WEEK

fig, axes = plt.subplots(2,2,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Comparison of Median and Mean for the ride lengths for spring season: Day of the week', fontsize = 25)

# set titles
axes[0,0].set_title('MEAN RIDE LENGTH', fontsize = 18)
axes[0,1].set_title('MEDIAN RIDE LENGTH', fontsize = 18)

sns.barplot(ax=axes[0, 0], x='day_of_week', y = 'mean_ride_minutes', hue = 'member_casual', data = s_meanday_df)
sns.barplot(ax=axes[0, 1], x='day_of_week', y = 'median_ride_minutes', hue = 'member_casual', data = s_medianday_df)

# Delete the subplot [1,0] and [1,1] that are not needed
fig.delaxes(axes[1,0]) #The indexing is zero-based here
fig.delaxes(axes[1,1]) #The indexing is zero-based here

# %% [markdown]
# ### Observation
#
# The mean ride lengths for casual riders is expectionally higher than the member riders throughout the entire week during the spring season.
#
# Looking at the median, we release that the difference is not very high, but casual ride lengths are still more than the member ride lengths.
#
# And member ride lengths remain consistent throughout the week.

# %% [markdown]
# ###  FINDING THE TOTAL RIDES FOR SPRING SEASON
#     1. MONTHS
#     2. DAY OF WEEK
#     3. DAY OF WEEK and TIMEZONE
#     4. TIME OF DAY AND TIMEZONE

# %% [markdown]
# 1. Analysis of TOTAL RIDES for casual and member riders in Spring: MONTHS

# %%
# Order the months in the right order: March, April, May
springs = [ 'March', 'April', 'May'] 
from pandas.api.types import CategoricalDtype 
cat_type = CategoricalDtype(categories=springs, ordered=True) 
spring_df['month'] = spring_df['month'].astype(cat_type)

# %%
#Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
springdata = spring_df.groupby(['member_casual','month'], as_index = False)['ride_id'].count()

springdata['riders_percent'] = round((springdata['ride_id'] / springdata['ride_id'].sum()) * 100, 2)

springdata
# Out:
#   member_casual  month  ride_id  riders_percent
# 0        casual  March    89857            6.97
# 1        casual  April   126383            9.80
# 2        casual    May   280373           21.74
# 3        member  March   194119           15.05
# 4        member  April   244788           18.98
# 5        member    May   354388           27.47

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.barplot(x = 'month', y = 'ride_id', hue = 'member_casual', data = springdata)
springdata.groupby(['member_casual', 'month']).count()
plt.title('Total Rides for months in spring', fontsize=18)
ax.set_xlabel("\n Months \n", fontsize=20)
ax.set_ylabel("\nTOTAL RIDES\n", fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Percentage of casual riders in spring season

# %%
# split data frame into two 
member_spring, casual_spring = [x for _, x in springdata.groupby(springdata['member_casual'] == 'casual')]


# Plot a piechart showing percentage of casual riders for spring season

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(casual_spring['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Casual Riders: SPRING SEASON', fontsize = 20)
plt.legend(casual_spring['month'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Percentage of Member rides in spring season

# %%
# Plot a piechart showing percentage of member riders for spring season

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(member_spring['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Member Riders: SPRING SEASON', fontsize = 20)
plt.legend(member_spring['month'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Observation:
#
# During the month of March, 24% of member rides use the divvy bikes against only 18% of Casual riders.
#
# In May, the casual riders increase to 56%, compared to 45% of member riders. This increase can be related due the temparatures warming up in May.

# %% [markdown]
# ### 2. Analysis of TOTAL RIDERS members and casual in Spring: DAYS OF WEEK

# %%
# Order the days of week in the right order: 
springday = [ 'Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']
from pandas.api.types import CategoricalDtype
cat_type1 = CategoricalDtype(categories=springday, ordered=True)
spring_df['day_of_week'] = spring_df['day_of_week'].astype(cat_type1)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
springdaydata = spring_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_id'].count()

springdaydata['riders_percent'] = round((springdaydata['ride_id'] / springdaydata['ride_id'].sum()) * 100, 2)

springdaydata
# Out:
#    member_casual day_of_week  ride_id  riders_percent
# 0         casual      Monday    74244            5.76
# 1         casual     Tuesday    59867            4.64
# 2         casual   Wednesday    49141            3.81
# 3         casual    Thursday    61930            4.80
# 4         casual      Friday    56147            4.35
# 5         casual    Saturday   103340            8.01
# 6         casual      Sunday    91944            7.13
# 7         member      Monday   125472            9.73
# 8         member     Tuesday   134321           10.41
# 9         member   Wednesday   113446            8.79
# 10        member    Thursday   122270            9.48
# 11        member      Friday    98653            7.65
# 12        member    Saturday   102552            7.95
# 13        member      Sunday    96581            7.49

# %% [markdown]
# ### Percentage of Total Casual rides in spring season: DAYS OF WEEK

# %%
# split data frame into two 
member_springday, casual_springday = [x for _, x in springdaydata.groupby(springdaydata['member_casual'] == 'casual')]

# %%
# Plot a piechart showing percentage of casual riders for spring season:Day of week

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(casual_springday['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Casual Riders: SPRING SEASON:day of week', fontsize = 20)
plt.legend(casual_springday['day_of_week'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Percentage of Total Member rides in Spring: DAYS OF WEEK

# %%
# Plot a piechart showing percentage of member riders for spring season:Day of week

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(member_springday['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Member Riders: SPRING SEASON:day of week', fontsize = 20)
plt.legend(member_springday['day_of_week'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Observation
# SPRING SEASON: DAYS OF WEEK
#
# The casual riders amount to 40% total rides during the weekends. Whereas the casual riders only amount to 25% total rides on weekends.
#
# Member riders are more than the casual riders during the weekdays.

# %% [markdown]
# ### Observation
# By observing the trend of total rides for days of the week and duration time slots:
#
# 1. Member Riders follow a certain pattern:
#     The total rides by member riders is highest during the weekdays, with the largest no.of rides of duration less than 15 minutes.
#     The weekeends see the lowest ride count for the member riders, with the maximum rides lasting less than 15 minutes.
# 2. Casual Riders a different trend is seen:
#     The total rides by casual riders is highest during the weekends, with the largest no.of rides of duration less than 15 minutes,
#     followed by rides of duration between 15 and 30 minutes.

# %% [markdown]
# ### Observation
# Member riders trends:
#
# Maximum no.of rides greater than 200,000 occur during PM times for a ride duration of 0-15 minutes.
# Lowest no.of rides are during the Late hours.
# The least rides have duration times of 45 and above.
# Casual riders trends:
#
# Maximum no.of rides about 100,000 occur during PM times, for a ride duration of 0-15 minutes.
# Lowest no.of rides are during AM hours, with the duration times exceeding 45 minutes during AM hours.

# %% [markdown]
# ## ANLAYSIS FOR RIDER BEHAVIOR FOR ALL 4 SEASONS: SPRING, SUMMER, FALL, WINTER

# %% [markdown]
# ### FIND THE TOTAL RIDES FOR MEMBER AND CASUAL RIDERS ALL SEASONS
#
#     1. SEASONS
#     2. TIMES OF DAY
#     3. TIMEZONES
#     4. DAYS OF WEEK
#     5. DAY OF WEEK and TIMEZONE
#     6. TIME OF DAY AND TIMEZONE

# %% [markdown]
# ### 1. Analysis of TOTAL RIDES member and casual for ALL SEASONS.
#
# Summer season: JULY, AUGUST, SEPTEMBER

# %% [markdown]
# #### For summer months : July, August and September

# %%
summer_df['month'] = summer_df['started_at'].dt.month_name()

# %% [markdown]
#  Table showing the MEDIAN and MEAN ride length for both member and casual riders for each of the week

# %%
#summer_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)
#summer_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].mean(numeric_only=False)

# %% [markdown]
# Table showing the MEANand MEDIAN ride length for both member and casual riders for the time of day

# %%
#summer_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
#summer_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only=False)

# %% [markdown]
# #### For fall months : October, November and December

# %%
fall_df['month'] = fall_df['started_at'].dt.month_name()

# %% [markdown]
# Table showing the MEAN and MEDIAN ride length for both member and casual riders for each of the week

# %%
#fall_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].mean(numeric_only=False)
#fall_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)

# %% [markdown]
#  Table showing the MEAN and MEDIAN ride length for both member and casual riders for time of day

# %%
#fall_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only=False)
#fall_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)

# %% [markdown]
# #### For winter months : January, February and March

# %%
winter_df['month'] = winter_df['started_at'].dt.month_name()

# %% [markdown]
#  Table showing the MEAN and MEDIAN ride length for both member and casual riders for each of the week

# %%
#winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)
#winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].mean(numeric_only=False)

# %% [markdown]
# Table showing the MEAN and MEDIAN ride length for both member and casual riders for time of day

# %%
#winter_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only=False)
#winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)

# %% [markdown]
# Table showing the MEAN and MEDIAN ride length for both member and casual riders for each of the week

# %%
#winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].mean(numeric_only=False)
#winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)

# %% [markdown]
# Table showing the MEAN and MEDIAN ride length for both member and casual riders for time of day

# %%
#winter_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only=False)
#winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)

# %%
# Order the months in the right order: June, July, August
summerm = [ 'June', 'July', 'August']
from pandas.api.types import CategoricalDtype
cat_types = CategoricalDtype(categories=summerm, ordered=True)
summer_df['month'] = summer_df['month'].astype(cat_types)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
summerdata = summer_df.groupby(['member_casual','month'], as_index = False)['ride_id'].count()

summerdata['riders_percent'] = round((summerdata['ride_id'] / summerdata['ride_id'].sum()) * 100, 2)

summerdata
# Out:
#   member_casual   month  ride_id  riders_percent
# 0        casual    June   368937           15.40
# 1        casual    July   405927           16.94
# 2        casual  August   412532           17.22
# 3        member    June   400029           16.69
# 4        member    July   417316           17.41
# 5        member  August   391576           16.34

# %%
# Order the months in the right order: September, October, November
fallm = [ 'September', 'October', 'November']
from pandas.api.types import CategoricalDtype
cat_typef = CategoricalDtype(categories=fallm, ordered=True)
fall_df['month'] = fall_df['month'].astype(cat_typef)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
falldata = fall_df.groupby(['member_casual','month'], as_index = False)['ride_id'].count()

falldata['riders_percent'] = round((falldata['ride_id'] / falldata['ride_id'].sum()) * 100, 2)

falldata
# Out:
#   member_casual      month  ride_id  riders_percent
# 0        casual  September   363772           20.83
# 1        casual    October   257137           14.72
# 2        casual   November   106873            6.12
# 3        member  September   392112           22.45
# 4        member    October   373872           21.40
# 5        member   November   252975           14.48

# %%
# Order the months in the right order: December, January, February
winterm = [ 'December', 'January', 'February']
from pandas.api.types import CategoricalDtype
cat_typew = CategoricalDtype(categories=winterm, ordered=True)
winter_df['month'] = winter_df['month'].astype(cat_typew)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
winterdata = winter_df.groupby(['member_casual','month'], as_index = False)['ride_id'].count()

winterdata['riders_percent'] = round((winterdata['ride_id'] / winterdata['ride_id'].sum()) * 100, 2)

winterdata
# Out:
#   member_casual     month  ride_id  riders_percent
# 0        casual  December    69729           14.94
# 1        casual   January    18515            3.97
# 2        casual  February    21412            4.59
# 3        member  December   177780           38.08
# 4        member   January    85243           18.26
# 5        member  February    94181           20.17

# %%
# Concatenate the dataframes spring, summer, fall, winter

frames = [spring_df, summer_df, fall_df, winter_df]

result = pd.concat(frames)


result['season'] = np.where((result['month'] == 'March') & (result['month'] == 'April') & (result['month'] == 'May'),'Spring',
                      np.where((result['month'] == 'June') & (result['month'] == 'July') & (result['month'] == 'August'),'Summer',
                      np.where((result['month'] == 'September') & (result['month'] == 'October') & (result['month'] == 'November'),'Fall', 'Winter')))

# %% [markdown]
# ### Total rides for the 4 seasons: Spring, Summer, Fall, Winter

# %%
# Plot the seasons side by side to compare the total rides

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides for the 4 seasons: Spring, Summer, Fall, Winter', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='month', y = 'ride_id', hue = 'member_casual', data = springdata)
sns.barplot(ax=axes[0, 1], x='month', y = 'ride_id', hue = 'member_casual', data = summerdata)
sns.barplot(ax=axes[1, 0], x='month', y = 'ride_id', hue = 'member_casual', data = falldata)
sns.barplot(ax=axes[1, 1], x='month', y = 'ride_id', hue = 'member_casual', data = winterdata)

# %% [markdown]
# ### Observation
#
# Trends that are seen:
#
#     1. The coldest months of the year: January, February see a drop in the usage of Divvy bikes for both kinds of riders.
#     2. January and february see the LEAST number ( less than 5000 rides) for casual riders.
#     3. The total rides keep on increasing as we go into the spring and summer months, with summer months seeing the maximum rides for both rider groups.
#     4. Going into fall season, the total rides keep on decreaing as we reach December.
#     5. In all scenarios, the total member riders are higher than total casual rides, except August which sees a slightly higher casual rides than member rides.
#     6. All the summer months, show large number of rides for both rider groups, which July totaling to slightly more than 400000 rides for member riders
#        and about 400000 total rides for casual riders.

# %% [markdown]
# ### Conclusion:
#
#     The weather highly affects the way users both member and casual use the Divvy Bikes.

# %% [markdown]
# ### 2. Analysis of TOTAL RIDES members and casual ALL SEASONS: TIMES OF DAY

# %%
# Order the times of day in the right order: 
time = [ 'AM', 'MID','PM','Late']
from pandas.api.types import CategoricalDtype
cat_type2 = CategoricalDtype(categories=time, ordered=True)

spring_df['time_of_day'] = spring_df['time_of_day'].astype(cat_type2)
summer_df['time_of_day'] = summer_df['time_of_day'].astype(cat_type2)
fall_df['time_of_day'] = fall_df['time_of_day'].astype(cat_type2)
winter_df['time_of_day'] = winter_df['time_of_day'].astype(cat_type2)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
springtimedata = spring_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_id'].count()

springtimedata['riders_percent'] = round((springtimedata['ride_id'] / springtimedata['ride_id'].sum()) * 100, 2)


summertimedata = summer_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_id'].count()

summertimedata['riders_percent'] = round((summertimedata['ride_id'] / summertimedata['ride_id'].sum()) * 100, 2)

falltimedata = fall_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_id'].count()

falltimedata['riders_percent'] = round((falltimedata['ride_id'] / falltimedata['ride_id'].sum()) * 100, 2)

wintertimedata = winter_df.groupby(['member_casual','time_of_day'], as_index = False)['ride_id'].count()

wintertimedata['riders_percent'] = round((wintertimedata['ride_id'] / wintertimedata['ride_id'].sum()) * 100, 2)

# %%
# split data frame into two 
member_springtime, casual_springtime = [x for _, x in springtimedata.groupby(springtimedata['member_casual'] == 'casual')]
member_summertime, casual_summertime = [x for _, x in summertimedata.groupby(summertimedata['member_casual'] == 'casual')]
member_falltime, casual_falltime = [x for _, x in falltimedata.groupby(falltimedata['member_casual'] == 'casual')]
member_wintertime, casual_wintertime = [x for _, x in wintertimedata.groupby(wintertimedata['member_casual'] == 'casual')]

# %% [markdown]
# ### Percentage of Total Member riders for all 4 seasons: TIMES OF DAY

# %%
# Plot the percentages of total member rides for all 4 seasons:TIMES OF DAY
labels = 'AM', 'MID', 'PM', 'Late'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Member rides for Spring, Summer, Fall and Winter:TIMES OF DAY", fontsize=18)

# A standard pie plot
axs[0, 0].pie(member_springtime['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(member_summertime['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(member_falltime['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(member_wintertime['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Observation
#
# COMPARISON OF TOTAL RIDES FOR MEMBERS RIDERS FOR ALL 4 SEASONS DURING THE TIMES OF THE DAY:
#
# For Member riders:
#
#     22% of total rides are during the AM Hours.
#     39% of the total rides are in the PM hours.
#     Less than 14% of rides are in the late hours.

# %% [markdown]
# ### Percentage of Total Casual riders for all 4 seasons: TIMES OF DAY

# %%
# Plot the percentages of total casual rides for all 4 seasons:TIMES OF DAY
labels = 'AM', 'MID', 'PM', 'Late'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Casual rides for Spring, Summer, Fall and Winter:TIMES OF DAY", fontsize=18)

# A standard pie plot
axs[0, 0].pie(casual_springtime['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(casual_summertime['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(casual_falltime['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(casual_wintertime['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Observation
#
# COMPARISON OF TOTAL RIDES FOR CASUAL RIDERS FOR ALL 4 SEASONS DURING THE TIMES OF THE DAY:
#
# For Casual riders:
#
# Majority of casual rides ( 37%-42%) are during the PM hours after 3:00pm and before 8:00pm
#
# Only 9%-11% rides are during the AM hours.
#
# Mid Morning hours see about 30% total rides
#
# Late hours see about 18% to 22% of rides.

# %% [markdown]
# ### 3. Analysis of TOTAL RIDES membe and casual riders ALL SEASONS: TIMEZONES

# %%
new_springdf = spring_df[['member_casual','day_of_week','time_of_day','ride_length','ride_id']].copy()
new_summerdf = summer_df[['member_casual','day_of_week','time_of_day','ride_length','ride_id']].copy()
new_falldf = fall_df[['member_casual','day_of_week','time_of_day','ride_length','ride_id']].copy()
new_winterdf = winter_df[['member_casual','day_of_week','time_of_day','ride_length','ride_id']].copy()

# %% [markdown]
# Create a new Category called timezone with the following classification:
# 0-15 minutes
#
# 15-30 minutes
#
# 30-45 minutes
#
# 45+ minutes

# %%
new_springdf['minutes'] = new_springdf['ride_length'].dt.total_seconds()/60
new_summerdf['minutes'] = new_summerdf['ride_length'].dt.total_seconds()/60
new_falldf['minutes'] = new_falldf['ride_length'].dt.total_seconds()/60
new_winterdf['minutes'] = new_winterdf['ride_length'].dt.total_seconds()/60

# %%
new_springdf['timezone'] = np.where((new_springdf['minutes'] >= 0) & (new_springdf['minutes'] <=15), '0-15min',
                      np.where((new_springdf['minutes'] >15) & (new_springdf['minutes'] <= 30 ), '15-30min',
                      np.where((new_springdf['minutes'] >30) & (new_springdf['minutes'] <= 45), '30-45min', '+45min')))
                        
new_summerdf['timezone'] = np.where((new_summerdf['minutes'] >= 0) & (new_summerdf['minutes'] <=15), '0-15min',
                      np.where((new_summerdf['minutes'] >15) & (new_summerdf['minutes'] <= 30 ), '15-30min',
                      np.where((new_summerdf['minutes'] >30) & (new_summerdf['minutes'] <= 45), '30-45min', '+45min')))
                
new_falldf['timezone'] = np.where((new_falldf['minutes'] >= 0) & (new_falldf['minutes'] <=15), '0-15min',
                      np.where((new_falldf['minutes'] >15) & (new_falldf['minutes'] <= 30 ), '15-30min',
                      np.where((new_falldf['minutes'] >30) & (new_falldf['minutes'] <= 45), '30-45min', '+45min')))
                    
new_winterdf['timezone'] = np.where((new_winterdf['minutes'] >= 0) & (new_winterdf['minutes'] <=15), '0-15min',
                      np.where((new_winterdf['minutes'] >15) & (new_winterdf['minutes'] <= 30 ), '15-30min',
                      np.where((new_winterdf['minutes'] >30) & (new_winterdf['minutes'] <= 45), '30-45min', '+45min')))

# %%
new_springdf1 = new_springdf[['member_casual','timezone','ride_id']].copy()
new_summerdf1 = new_summerdf[['member_casual','timezone','ride_id']].copy()
new_falldf1 = new_falldf[['member_casual','timezone','ride_id']].copy()
new_winterdf1 = new_winterdf[['member_casual','timezone','ride_id']].copy()

# %%
new_springdf1 = new_springdf1.groupby(['member_casual','timezone'], as_index = False).count()
new_summerdf1 = new_summerdf1.groupby(['member_casual','timezone'], as_index = False).count()
new_falldf1 = new_falldf1.groupby(['member_casual','timezone'], as_index = False).count()
new_winterdf1 = new_winterdf1.groupby(['member_casual','timezone'], as_index = False).count()

# %%
new_springdf1
# Out:
#   member_casual  timezone  ride_id
# 0        casual    +45min    61284
# 1        casual   0-15min   252515
# 2        casual  15-30min   133465
# 3        casual  30-45min    49349
# 4        member    +45min    12960
# 5        member   0-15min   593776
# 6        member  15-30min   147908
# 7        member  30-45min    38651

# %% [markdown]
# ### Comparison of the total rides in different timezone for casual and member riders in all 4 seasons.

# %%
# Plot the seasons side by side to compare the total rides for different TIMEZONES

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides for Spring, Summer, Fall, Winter: TIMEZONES', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='timezone', y = 'ride_id', hue = 'member_casual', data = new_springdf1)
sns.barplot(ax=axes[0, 1], x='timezone', y = 'ride_id', hue = 'member_casual', data = new_summerdf1)
sns.barplot(ax=axes[1, 0], x='timezone', y = 'ride_id', hue = 'member_casual', data = new_falldf1)
sns.barplot(ax=axes[1, 1], x='timezone', y = 'ride_id', hue = 'member_casual', data = new_winterdf1)

# %% [markdown]
# ### Observation
#
# Trends seen FOR MEMBERS and CASUAL riders for ALL Seasons:Time durations(TIMEZONES)
#
# 1. Member riders: Most no.of rides are less than 15 minutes long. Summer season, followed by Fall season sees the maximum no.of rides.
#
# 2. Casual riders: Most no.of rides are less than 15 minutes long. Summer season, followed by Fall season sees the maximum no.of rides.
#
# 3. For the timezone of less than 15 minutes -- the total member rides are higher than total casual rides for all seasons.
#
# 4. Overall, winter season sees the least no.of total rides for both casual and member riders.
#
# 5. The casual rides of more than 45 minutes are higher in number than member rides of same duration.
#
# 6. Also, casual rides of 30-45 minutes are more in number than member rides.
#
# CONCLUSION: The majority of member rides are in the timezone of less than 15 minutes.
#
# Compared to member riders, casual riders tend to take longer rides of more than 30 minutes.

# %% [markdown]
#   ### Find percentage of rides that fall into each TIMEZONE

# %%
# split data frame into two 
member_sd, casual_sd = [x for _, x in new_springdf1.groupby(new_springdf1['member_casual'] == 'casual')]
member_sud, casual_sud = [x for _, x in new_summerdf1.groupby(new_summerdf1['member_casual'] == 'casual')]
member_fd, casual_fd = [x for _, x in new_falldf1.groupby(new_falldf1['member_casual'] == 'casual')]
member_wd, casual_wd = [x for _, x in new_winterdf1.groupby(new_winterdf1['member_casual'] == 'casual')]

# %%
member_sd
# Out:
#   member_casual  timezone  ride_id
# 4        member    +45min    12960
# 5        member   0-15min   593776
# 6        member  15-30min   147908
# 7        member  30-45min    38651

# %% [markdown]
# ### Percentages of Total Member rides for Spring, Summer, Fall and Winter:TIMEZONES

# %%
# Plot the percentages of total member rides for all 4 seasons:TIMEZONES
labels = '+45Min', '0-15Min', '15-30Min', '30-45Min'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Member rides for Spring, Summer, Fall and Winter:TIMEZONES", fontsize=18)

# A standard pie plot
axs[0, 0].pie(member_sd['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(member_sud['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(member_fd['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(member_wd['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Observation
#
# ALL SEASONS: TOTAL RIDES IN TIMEZONES FOR MEMBER RIDERS:
#
# Majority of rides, between 70% to 80%, have ride durations less than 15 minutes.
#
# Only 2% of member rides are more than 45+ minutes long

# %% [markdown]
# ### Percentages of Total Casual rides for Spring, Summer, Fall and Winter:TIMEZONES

# %%
# Plot the percentages of total member rides for all 4 seasons:TIMEZONES
labels = '+45Min', '0-15Min', '15-30Min', '30-45Min'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Casual rides for Spring, Summer, Fall and Winter:TIMEZONES", fontsize=18)

# A standard pie plot
axs[0, 0].pie(casual_sd['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(casual_sud['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(casual_fd['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(casual_wd['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Observation
#
# ALL SEASONS: TOTAL RIDES IN TIMEZONES FOR CASUAL RIDERS:
#
# 51% to 65% casual rides are less than 15 minutes in all the 4 seasons.
#
# Except in winter months, 12% of casual rides are for more than 45 minutes.

# %% [markdown]
# ### 4. Analysis of TOTAL RIDES for casual and member riders ALL SEASON: DAYS OF WEEK

# %%
# Order the days of week in the right order: 
springday = [ 'Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']
from pandas.api.types import CategoricalDtype
cat_type1 = CategoricalDtype(categories=springday, ordered=True)
spring_df['day_of_week'] = spring_df['day_of_week'].astype(cat_type1)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
springdaydata = spring_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_id'].count()

springdaydata['riders_percent'] = round((springdaydata['ride_id'] / springdaydata['ride_id'].sum()) * 100, 2)
# Out:
#    member_casual day_of_week  ride_id  riders_percent
# 0         casual      Monday    74244            5.76
# 1         casual     Tuesday    59867            4.64
# 2         casual   Wednesday    49141            3.81
# 3         casual    Thursday    61930            4.80
# 4         casual      Friday    56147            4.35
# 5         casual    Saturday   103340            8.01
# 6         casual      Sunday    91944            7.13
# 7         member      Monday   125472            9.73
# 8         member     Tuesday   134321           10.41
# 9         member   Wednesday   113446            8.79
# 10        member    Thursday   122270            9.48
# 11        member      Friday    98653            7.65
# 12        member    Saturday   102552            7.95
# 13        member      Sunday    96581            7.49

# %%
# Order the days of week in the right order: 
summerday = [ 'Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']
from pandas.api.types import CategoricalDtype
cat_type2 = CategoricalDtype(categories=summerday, ordered=True)
summer_df['day_of_week'] = summer_df['day_of_week'].astype(cat_type2)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
summerdaydata = summer_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_id'].count()

summerdaydata['riders_percent'] = round((summerdaydata['ride_id'] / summerdaydata['ride_id'].sum()) * 100, 2)

#summerdaydata

# %%
# Order the days of week in the right order: 
fallday = [ 'Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']
from pandas.api.types import CategoricalDtype
cat_type3 = CategoricalDtype(categories=fallday, ordered=True)
fall_df['day_of_week'] = fall_df['day_of_week'].astype(cat_type3)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
falldaydata = fall_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_id'].count()

falldaydata['riders_percent'] = round((falldaydata['ride_id'] / falldaydata['ride_id'].sum()) * 100, 2)

#falldaydata

# %%
# Order the days of week in the right order: 
winterday = [ 'Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']
from pandas.api.types import CategoricalDtype
cat_type4 = CategoricalDtype(categories=winterday, ordered=True)
winter_df['day_of_week'] = winter_df['day_of_week'].astype(cat_type4)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and member riders
winterdaydata = winter_df.groupby(['member_casual','day_of_week'], as_index = False)['ride_id'].count()

winterdaydata['riders_percent'] = round((winterdaydata['ride_id'] / winterdaydata['ride_id'].sum()) * 100, 2)

#winterdaydata

# %% [markdown]
# ### Total member and casual rides for the 4 seasons: DAYS OF WEEK

# %%
# Plot the seasons side by side to compare the total rides for days of the week

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides for days of the week for the 4 seasons', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='day_of_week', y = 'ride_id', hue = 'member_casual', data = springdaydata)
sns.barplot(ax=axes[0, 1], x='day_of_week', y = 'ride_id', hue = 'member_casual', data = summerdaydata)
sns.barplot(ax=axes[1, 0], x='day_of_week', y = 'ride_id', hue = 'member_casual', data = falldaydata)
sns.barplot(ax=axes[1, 1], x='day_of_week', y = 'ride_id', hue = 'member_casual', data = winterdaydata)

# %% [markdown]
# ### Observation
#
# Casual riders have highest no.of rides in summer season on saturdays and sundays, followed by fall season.
#
# Trend for Casual riders and member riders:
#     Casual riders have highest no.of rides on weekends.
#
#     Casual riders conssistenly increase from spring to summer peaking in summer, and then start going down in
#     numbers in fall, with least rides suring winter season.
#
#     Member riders also peak during summer and fall months and show least numbers in winter.
#
#     Weekend rides for members are less in count than on weekends for all seasons.

# %% [markdown]
# ### Plot the percentages of total member and casual rides for all 4 seasons:Days of the week

# %%
member_spring, casual_spring = [x for _, x in springdaydata.groupby(springdaydata['member_casual'] == 'casual')]

# %%
member_summer, casual_summer = [x for _, x in summerdaydata.groupby(summerdaydata['member_casual'] == 'casual')]

# %%
member_fall, casual_fall = [x for _, x in falldaydata.groupby(falldaydata['member_casual'] == 'casual')]
# Out:
#    member_casual day_of_week  ride_id  riders_percent
# 0         casual      Monday    80762            4.62
# 1         casual     Tuesday    75047            4.30
# 2         casual   Wednesday    85636            4.90
# 3         casual    Thursday    83939            4.81
# 4         casual      Friday   101853            5.83
# 5         casual    Saturday   160736            9.20
# 6         casual      Sunday   139809            8.00
# 7         member      Monday   135886            7.78
# 8         member     Tuesday   160641            9.20
# 9         member   Wednesday   166958            9.56
# 10        member    Thursday   150078            8.59
# 11        member      Friday   142695            8.17
# 12        member    Saturday   140963            8.07
# 13        member      Sunday   121738            6.97

# %%
member_winter, casual_winter = [x for _, x in winterdaydata.groupby(winterdaydata['member_casual'] == 'casual')]
# Out:
#    member_casual day_of_week  ride_id  riders_percent
# 0         casual      Monday    14585            3.12
# 1         casual     Tuesday    11442            2.45
# 2         casual   Wednesday    15662            3.35
# 3         casual    Thursday    17007            3.64
# 4         casual      Friday    17993            3.85
# 5         casual    Saturday    17753            3.80
# 6         casual      Sunday    15214            3.26
# 7         member      Monday    54217           11.61
# 8         member     Tuesday    52148           11.17
# 9         member   Wednesday    61421           13.16
# 10        member    Thursday    60780           13.02
# 11        member      Friday    52765           11.30
# 12        member    Saturday    39701            8.50
# 13        member      Sunday    36172            7.75

# %%
# Plot the percentages of total member rides for all 4 seasons:Days of the week
labels = 'Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday','Sunday'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Member rides for Spring, Summer, Fall and Winter:Days of week", fontsize=18)

# A standard pie plot
axs[0, 0].pie(member_spring['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(member_summer['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(member_fall['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(member_winter['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Observation
#
# For Member riders:
#
#     The percentages of total member rides is lowest in winter season on saturday and sunday (10-11%)
#     Spring, Summer, Winter months see consistent ride percentages all weekdays (12%-15%)

# %%
# Plot the percentages of total casual rides for all 4 seasons:Days of week
labels = 'Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday','Sunday'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Casual rides for Spring, Summer, Fall and Winter:Days of week", fontsize=18)

# A standard pie plot
axs[0, 0].pie(casual_spring['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(casual_summer['ride_id'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(casual_fall['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(casual_winter['ride_id'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Observation
#
# Casual Riders:
#
# Summer, fall and spring have max rides during weekends about 41% and about 60% of rides are during the weekdays.
#
# Winter season has a drop in overall use of bikes during the weekends, with 69% during the week, and only 30% during weekend.

# %% [markdown]
# ### 5. Find TOTAL RIDES  for casual and member riders ALL SEASONS: DAY OF WEEK and  TIMEZONE

# %%
# SPRING
# split data frame into two 
member_st, casual_st = [x for _, x in new_springdf.groupby(new_springdf['member_casual'] == 'casual')]

# SUMMER
# split data frame into two 
member_sumt, casual_sumt = [x for _, x in new_summerdf.groupby(new_summerdf['member_casual'] == 'casual')]

# Fall
# split data frame into two 
member_ft, casual_ft = [x for _, x in new_falldf.groupby(new_falldf['member_casual'] == 'casual')]

# Winter
# split data frame into two 
member_wt, casual_wt = [x for _, x in new_winterdf.groupby(new_winterdf['member_casual'] == 'casual')]

# %%
# For Member riders: spring
spring_member = member_st.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
spring_member = spring_member.reset_index()
spring_member.reset_index()
# Out:
#     index day_of_week  timezone  ride_id
# 0       0      Monday    +45min     2062
# 1       1      Monday   0-15min    93452
# 2       2      Monday  15-30min    23478
# 3       3      Monday  30-45min     6480
# 4       4     Tuesday    +45min     1488
# 5       5     Tuesday   0-15min   103895
# 6       6     Tuesday  15-30min    23490
# 7       7     Tuesday  30-45min     5448
# 8       8   Wednesday    +45min     1417
# 9       9   Wednesday   0-15min    87786
# 10     10   Wednesday  15-30min    19643
# 11     11   Wednesday  30-45min     4600
# 12     12    Thursday    +45min     1571
# 13     13    Thursday   0-15min    93201
# 14     14    Thursday  15-30min    22104
# 15     15    Thursday  30-45min     5394
# 16     16      Friday    +45min     1333
# 17     17      Friday   0-15min    76467
# 18     18      Friday  15-30min    16815
# 19     19      Friday  30-45min     4038
# 20     20    Saturday    +45min     2673
# 21     21    Saturday   0-15min    71098
# ...

# %%
# For Member riders: summer
summer_member = member_sumt.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
summer_member = summer_member.reset_index()
summer_member.reset_index()
# Out:
#     index day_of_week  timezone  ride_id
# 0       0      Friday    +45min     3044
# 1       1      Friday   0-15min   120953
# 2       2      Friday  15-30min    38346
# 3       3      Friday  30-45min     9459
# 4       4      Monday    +45min     2934
# 5       5      Monday   0-15min   111856
# 6       6      Monday  15-30min    33525
# 7       7      Monday  30-45min     8592
# 8       8    Saturday    +45min     4790
# 9       9    Saturday   0-15min   108866
# 10     10    Saturday  15-30min    43616
# 11     11    Saturday  30-45min    12414
# 12     12      Sunday    +45min     5197
# 13     13      Sunday   0-15min   104773
# 14     14      Sunday  15-30min    42359
# 15     15      Sunday  30-45min    12584
# 16     16    Thursday    +45min     3108
# 17     17    Thursday   0-15min   134198
# 18     18    Thursday  15-30min    42035
# 19     19    Thursday  30-45min     9805
# 20     20     Tuesday    +45min     2664
# 21     21     Tuesday   0-15min   127216
# ...

# %%
# For Member riders: fall
fall_member = member_ft.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
fall_member = fall_member.reset_index()
fall_member.reset_index()
# Out:
#     index day_of_week  timezone  ride_id
# 0       0      Friday    +45min     2026
# 1       1      Friday   0-15min   106834
# 2       2      Friday  15-30min    27366
# 3       3      Friday  30-45min     6469
# 4       4      Monday    +45min     1989
# 5       5      Monday   0-15min   103730
# 6       6      Monday  15-30min    24125
# 7       7      Monday  30-45min     6042
# 8       8    Saturday    +45min     3241
# 9       9    Saturday   0-15min    97476
# 10     10    Saturday  15-30min    31371
# 11     11    Saturday  30-45min     8875
# 12     12      Sunday    +45min     3162
# 13     13      Sunday   0-15min    83714
# 14     14      Sunday  15-30min    26849
# 15     15      Sunday  30-45min     8013
# 16     16    Thursday    +45min     1863
# 17     17    Thursday   0-15min   114937
# 18     18    Thursday  15-30min    27208
# 19     19    Thursday  30-45min     6070
# 20     20     Tuesday    +45min     1775
# 21     21     Tuesday   0-15min   124344
# ...

# %%
# For Member riders: winter
winter_member = member_wt.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
winter_member = winter_member.reset_index()
winter_member.reset_index()
# Out:
#     index day_of_week  timezone  ride_id
# 0       0      Friday    +45min      643
# 1       1      Friday   0-15min    42392
# 2       2      Friday  15-30min     7929
# 3       3      Friday  30-45min     1801
# 4       4      Monday    +45min      589
# 5       5      Monday   0-15min    43678
# 6       6      Monday  15-30min     8098
# 7       7      Monday  30-45min     1852
# 8       8    Saturday    +45min      530
# 9       9    Saturday   0-15min    31351
# 10     10    Saturday  15-30min     6373
# 11     11    Saturday  30-45min     1447
# 12     12      Sunday    +45min      641
# 13     13      Sunday   0-15min    28301
# 14     14      Sunday  15-30min     5732
# 15     15      Sunday  30-45min     1498
# 16     16    Thursday    +45min      621
# 17     17    Thursday   0-15min    49227
# 18     18    Thursday  15-30min     9021
# 19     19    Thursday  30-45min     1911
# 20     20     Tuesday    +45min      537
# 21     21     Tuesday   0-15min    42555
# ...

# %%
# Plot the seasons side by side to compare the total rides (member riders) for different TIMES OF DAY

fig, axes = plt.subplots(2,2,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides (member) for Spring, Summer, Fall, Winter: TIMEZONES AND DAYS OF WEEK', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

sns.barplot(ax=axes[0, 0], x='day_of_week', y = 'ride_id', hue = 'timezone', data = spring_member)
sns.barplot(ax=axes[0, 1], x='day_of_week', y = 'ride_id', hue = 'timezone', data = summer_member)
sns.barplot(ax=axes[1, 0], x='day_of_week', y = 'ride_id', hue = 'timezone', data = fall_member)
sns.barplot(ax=axes[1, 1], x='day_of_week', y = 'ride_id', hue = 'timezone', data = winter_member)

# %% [markdown]
# ### Observation
#
# Behavior pattern for member riders during different seasons, Day of week and duration of rides.
#
# Summer season has the highest no.of rides, followed by fall, spring and winter.
# In summer season, maximum rides take place during weekedays. These rides are less than 15 minutes long.
#
# Winter season has the least no.of rides. The maximum rides being less than 15 minutes long.
# For all seasons, the weekends see the least no.of rides for all durations of rides.

# %%
# For Casual riders:spring
spring_casual = casual_st.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
spring_casual = spring_casual.reset_index()

# %%
# For Casual riders:summer
summer_casual = casual_sumt.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
summer_casual = summer_casual.reset_index()

# %%
# For Casual riders:fall
fall_casual = casual_ft.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
fall_casual = fall_casual.reset_index()

# %%
# For Casual riders:winter
winter_casual = casual_wt.groupby(['day_of_week','timezone'])['ride_id'].count().to_frame()
winter_casual = winter_casual.reset_index()

# %%
# Plot the seasons side by side to compare the total rides(casual riders) for different TIMES OF DAY

fig, axes = plt.subplots(2,2,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides (casual) for Spring, Summer, Fall, Winter: TIMEZONES AND DAYS OF WEEK', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='day_of_week', y = 'ride_id', hue = 'timezone', data = spring_casual)
sns.barplot(ax=axes[0, 1], x='day_of_week', y = 'ride_id', hue = 'timezone', data = summer_casual)
sns.barplot(ax=axes[1, 0], x='day_of_week', y = 'ride_id', hue = 'timezone', data = fall_casual)
sns.barplot(ax=axes[1, 1], x='day_of_week', y = 'ride_id', hue = 'timezone', data = winter_casual)

# %% [markdown]
# ### Observation
#
# Behavior pattern for casual riders during different seasons, Day of week and duration of rides.
#
# Summer season has the highest no.of rides, followed by fall, spring and winter.
# In summer season, maximum rides take place on Saturdays and Sundays. These rides are less than 15 minutes long.
#
# Winter season has the least no.of rides. The maximum rides being less than 15 minutes long.

# %% [markdown]
# ### 4. Analysis of total rides for casual and member riders in spring: TIME OF DAY AND TIMEZONE

# %%
#split data frame into two 
member_sp, casual_sp = [x for _, x in new_springdf.groupby(new_springdf['member_casual'] == 'casual')]
member_sump, casual_sump = [x for _, x in new_summerdf.groupby(new_summerdf['member_casual'] == 'casual')]
member_fp, casual_fp = [x for _, x in new_falldf.groupby(new_falldf['member_casual'] == 'casual')]
member_wp, casual_wp = [x for _, x in new_winterdf.groupby(new_winterdf['member_casual'] == 'casual')]

# %%
spring_member = member_sp.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()
spring_member = spring_member.reset_index()
spring_member.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min     1359
# 1       1          AM   0-15min   123573
# 2       2          AM  15-30min    26446
# 3       3          AM  30-45min     5762
# 4       4         MID    +45min     4367
# 5       5         MID   0-15min   157036
# 6       6         MID  15-30min    37457
# 7       7         MID  30-45min    11228
# 8       8          PM    +45min     5827
# 9       9          PM   0-15min   233359
# 10     10          PM  15-30min    65020
# 11     11          PM  30-45min    17479
# 12     12        Late    +45min     1407
# 13     13        Late   0-15min    79808
# 14     14        Late  15-30min    18985
# 15     15        Late  30-45min     4182

# %%
summer_member = member_sump.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()
summer_member = summer_member.reset_index()
summer_member.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min     2598
# 1       1          AM   0-15min   164523
# 2       2          AM  15-30min    45556
# 3       3          AM  30-45min    10350
# 4       4         MID    +45min     7529
# 5       5         MID   0-15min   207527
# 6       6         MID  15-30min    64680
# 7       7         MID  30-45min    18745
# 8       8          PM    +45min    10698
# 9       9          PM   0-15min   330664
# 10     10          PM  15-30min   119389
# 11     11          PM  30-45min    31180
# 12     12        Late    +45min     3623
# 13     13        Late   0-15min   134991
# 14     14        Late  15-30min    46470
# 15     15        Late  30-45min    10398

# %%
fall_member = member_fp.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()
fall_member = fall_member.reset_index()
fall_member.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min     2158
# 1       1          AM   0-15min   153886
# 2       2          AM  15-30min    35876
# 3       3          AM  30-45min     7806
# 4       4         MID    +45min     5291
# 5       5         MID   0-15min   203135
# 6       6         MID  15-30min    49525
# 7       7         MID  30-45min    14029
# 8       8          PM    +45min     6602
# 9       9          PM   0-15min   295169
# 10     10          PM  15-30min    84033
# 11     11          PM  30-45min    21201
# 12     12        Late    +45min     1977
# 13     13        Late   0-15min   105939
# 14     14        Late  15-30min    26347
# 15     15        Late  30-45min     5985

# %%
winter_member = member_wp.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()
winter_member = winter_member.reset_index()
winter_member.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min      644
# 1       1          AM   0-15min    62977
# 2       2          AM  15-30min    11186
# 3       3          AM  30-45min     2185
# 4       4         MID    +45min     1308
# 5       5         MID   0-15min    82522
# 6       6         MID  15-30min    14666
# 7       7         MID  30-45min     3674
# 8       8          PM    +45min     1763
# 9       9          PM   0-15min   109298
# 10     10          PM  15-30min    21772
# 11     11          PM  30-45min     4812
# 12     12        Late    +45min      455
# 13     13        Late   0-15min    32663
# 14     14        Late  15-30min     6062
# 15     15        Late  30-45min     1217

# %%
#Plot Total Member Rides in Spring season for Time of Day and TimeZones

# %%
# Plot the seasons side by side to compare the total rides(member riders) for different TIMES OF DAY & TIMEZONE

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides (member) for Spring, Summer, Fall, Winter: TIME OF DAY AND TIMEZONE', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'ride_id', hue = 'timezone', data = spring_member)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'ride_id', hue = 'timezone', data = summer_member)
sns.barplot(ax=axes[1, 0], x='time_of_day', y = 'ride_id', hue = 'timezone', data = fall_member)
sns.barplot(ax=axes[1, 1], x='time_of_day', y = 'ride_id', hue = 'timezone', data = winter_member)

# %% [markdown]
# ### Observation
# Behavior pattern for member riders during different seasons, time of day and duration of rides
#
# Summer season has the highest no.of rides, followed by fall, spring and winter. In summer season, maximum rides take place in the evening (PM) hours. These rides are less than 15 minutes long.
#
# Winter season has the least no.of rides. Again the most rides are in the PM hours, with duration of less than 15 minutes.

# %%
# Casual riders: spring
spring_casual = casual_sp.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()

spring_casual = spring_casual.reset_index()
spring_casual.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min     3621
# 1       1          AM   0-15min    30603
# 2       2          AM  15-30min    10440
# 3       3          AM  30-45min     2815
# 4       4         MID    +45min    24375
# 5       5         MID   0-15min    67964
# 6       6         MID  15-30min    41299
# 7       7         MID  30-45min    17540
# 8       8          PM    +45min    25136
# 9       9          PM   0-15min   102443
# 10     10          PM  15-30min    59059
# 11     11          PM  30-45min    21875
# 12     12        Late    +45min     8152
# 13     13        Late   0-15min    51505
# 14     14        Late  15-30min    22667
# 15     15        Late  30-45min     7119

# %%
# Casual riders: summer
summer_casual = casual_sump.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()

summer_casual = summer_casual.reset_index()
summer_casual.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min     9853
# 1       1          AM   0-15min    69624
# 2       2          AM  15-30min    24024
# 3       3          AM  30-45min     7170
# 4       4         MID    +45min    53480
# 5       5         MID   0-15min   148111
# 6       6         MID  15-30min    94664
# 7       7         MID  30-45min    38218
# 8       8          PM    +45min    53911
# 9       9          PM   0-15min   236571
# 10     10          PM  15-30min   143197
# 11     11          PM  30-45min    47957
# 12     12        Late    +45min    22692
# 13     13        Late   0-15min   145679
# 14     14        Late  15-30min    71202
# 15     15        Late  30-45min    21043

# %%
# Casual riders: fall
fall_casual = casual_fp.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()

fall_casual = fall_casual.reset_index()
fall_casual.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min     6662
# 1       1          AM   0-15min    50692
# 2       2          AM  15-30min    18644
# 3       3          AM  30-45min     5253
# 4       4         MID    +45min    33194
# 5       5         MID   0-15min   102908
# 6       6         MID  15-30min    61730
# 7       7         MID  30-45min    24744
# 8       8          PM    +45min    27399
# 9       9          PM   0-15min   147462
# 10     10          PM  15-30min    81647
# 11     11          PM  30-45min    26668
# 12     12        Late    +45min     9853
# 13     13        Late   0-15min    83759
# 14     14        Late  15-30min    37081
# 15     15        Late  30-45min    10086

# %%
# Casual riders: winter
winter_casual = casual_wp.groupby(['time_of_day','timezone'])['ride_id'].count().to_frame()

winter_casual = winter_casual.reset_index()
winter_casual.reset_index()
# Out:
#     index time_of_day  timezone  ride_id
# 0       0          AM    +45min      531
# 1       1          AM   0-15min    10166
# 2       2          AM  15-30min     2466
# 3       3          AM  30-45min      493
# 4       4         MID    +45min     2969
# 5       5         MID   0-15min    21158
# 6       6         MID  15-30min     8452
# 7       7         MID  30-45min     2701
# 8       8          PM    +45min     2371
# 9       9          PM   0-15min    26387
# 10     10          PM  15-30min     9533
# 11     11          PM  30-45min     2523
# 12     12        Late    +45min      915
# 13     13        Late   0-15min    13659
# 14     14        Late  15-30min     4312
# 15     15        Late  30-45min     1020

# %%
# Plot the seasons side by side to compare the total rides(casual riders) for different TIMES OF DAY & TIMEZONE

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides (casual) for Spring, Summer, Fall, Winter: TIME OF DAY AND TIMEZONE', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'ride_id', hue = 'timezone', data = spring_casual)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'ride_id', hue = 'timezone', data = summer_casual)
sns.barplot(ax=axes[1, 0], x='time_of_day', y = 'ride_id', hue = 'timezone', data = fall_casual)
sns.barplot(ax=axes[1, 1], x='time_of_day', y = 'ride_id', hue = 'timezone', data = winter_casual)

# %% [markdown]
# ### Observation
#
# Behavior pattern for casual riders during different seasons, time of day and duration of rides
#
# Summer season has the highest no.of rides, followed by fall, spring and winter.
# In summer season, maximum rides take place in the evening (PM) hours. These rides are less than 15 minutes long.
#
# Winter seson has the least no.of rides. Again the most rides are in the PM hours, with duration of less than 15 minutes.

# %% [markdown]
# ### FIND THE TOTAL RIDE LENGTH FOR MEMBER AND CASUAL RIDERS ALL SEASONS
#
#     1. TIMES OF DAY
#     2. TIMEZONES

# %% [markdown]
# ### 1. Analysis of TOTAL RIDE LENGTH for casual and member riders in ALL SEASON:  TIMES OF DAY

# %%
# Order the times of day in the right order: 
time = [ 'AM', 'MID','PM','Late']
from pandas.api.types import CategoricalDtype
cat_type2 = CategoricalDtype(categories=time, ordered=True)

new_springdf['time_of_day'] = spring_df['time_of_day'].astype(cat_type2)
new_summerdf['time_of_day'] = summer_df['time_of_day'].astype(cat_type2)
new_falldf['time_of_day'] = fall_df['time_of_day'].astype(cat_type2)
new_winterdf['time_of_day'] = winter_df['time_of_day'].astype(cat_type2)

# %%
new_springdf3 = new_springdf[['member_casual','time_of_day','ride_length']].copy()
new_summerdf3 = new_summerdf[['member_casual','time_of_day','ride_length']].copy()
new_falldf3 = new_falldf[['member_casual','time_of_day','ride_length']].copy()
new_winterdf3 = new_winterdf[['member_casual','time_of_day','ride_length']].copy()

# %%
new_springdf3 = new_springdf3.groupby(['member_casual','time_of_day'], as_index = False).count()
new_summerdf3 = new_summerdf3.groupby(['member_casual','time_of_day'], as_index = False).count()
new_falldf3 = new_falldf3.groupby(['member_casual','time_of_day'], as_index = False).count()
new_winterdf3 = new_winterdf3.groupby(['member_casual','time_of_day'], as_index = False).count()

# %%
new_springdf3
# Out:
#   member_casual time_of_day  ride_length
# 0        casual          AM        47479
# 1        casual         MID       151178
# 2        casual          PM       208513
# 3        casual        Late        89443
# 4        member          AM       157140
# 5        member         MID       210088
# 6        member          PM       321685
# 7        member        Late       104382

# %% [markdown]
# ### Total ride lengths for Spring, Summer, Fall, Winter: TIMES OF DAY

# %%
# Plot the seasons side by side to compare the total rides for different TIMES OF DAY

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total ride lengths for Spring, Summer, Fall, Winter: TIMES OF DAY', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

#axes.set_ylabel( "Total Rides" , size = 18 )



sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = new_springdf3)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = new_summerdf3)
sns.barplot(ax=axes[1, 0], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = new_falldf3)
sns.barplot(ax=axes[1, 1], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = new_winterdf3)

# %% [markdown]
# ### OBSERVATION
#
# Member rides have duration greater than casual rides for all the time periods.
#
# The maximum total ride durations for the PM times are the highest for both the casaul and member riders.
#
# The AM time slot see the least duration of rides for casual members and PM slot the highest.
#
# The late Night time slot has the lowest duration rides for member riders.

# %% [markdown]
# ### Find the Percentages of Total Member and Casual ride lengths for Spring, Summer, Fall and Winter:TIMES OF DAY

# %%
# split data frame into two 
member_spt, casual_spt = [x for _, x in new_springdf3.groupby(new_springdf3['member_casual'] == 'casual')]
member_sut, casual_sut = [x for _, x in new_summerdf3.groupby(new_summerdf3['member_casual'] == 'casual')]
member_ft, casual_ft = [x for _, x in new_falldf3.groupby(new_falldf3['member_casual'] == 'casual')]
member_wt, casual_wt = [x for _, x in new_winterdf3.groupby(new_winterdf3['member_casual'] == 'casual')]

# %%
member_spt
# Out:
#   member_casual time_of_day  ride_length
# 4        member          AM       157140
# 5        member         MID       210088
# 6        member          PM       321685
# 7        member        Late       104382

# %% [markdown]
# ### Percentages of Total Member ride lengths for Spring, Summer, Fall and Winter:TIMES OF DAY

# %%
# Plot the percentages of total member ride lengths for all 4 seasons:TIMES OF DAY
labels = 'AM', 'MID', 'PM', 'Late'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Member ride lengths for Spring, Summer, Fall and Winter:TIMES OF DAY", fontsize=18)

# A standard pie plot
axs[0, 0].pie(member_spt['ride_length'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(member_sut['ride_length'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(member_ft['ride_length'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(member_wt['ride_length'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### Percentages of Total Casual ride lengths for Spring, Summer, Fall and Winter:TIMES OF DAY

# %%
# Plot the percentages of total casual ride length for all 4 seasons:TIMES OF DAY
labels = 'AM', 'MID', 'PM', 'Late'

# Make figure and axes
fig, axs = plt.subplots(2, 2, figsize = (12, 10))
columns = ['Spring', 'Summer','Fall','Winter']
fig.suptitle("Percentages of Total Member ride Length for Spring, Summer, Fall and Winter:TIMES OF DAY", fontsize=18)

# A standard pie plot
axs[0, 0].pie(casual_spt['ride_length'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[0, 1].pie(casual_sut['ride_length'], labels=labels, autopct='%1.0f%%', shadow=True)
axs[1, 0].pie(casual_ft['ride_length'], labels=labels,autopct='%1.0f%%',shadow=True)
axs[1, 1].pie(casual_wt['ride_length'], labels=labels,autopct='%1.0f%%',shadow=True)
                                                                                    
#axs.legend(columns,title="Seasons",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))

axs[0,0].set_title('Spring')
axs[0,1].set_title('Summer')
axs[1,0].set_title('Fall')
axs[1,1].set_title('Winter')

plt.show()

# %% [markdown]
# ### 2. Analysis of TOTAL RIDE LENGTH for casual and member riders for ALL SEASONS: TIMEZONES

# %%
# Order the times of day in the right order: 
timez = [ '0-15min', '15-30min','30-45min','+45min']
from pandas.api.types import CategoricalDtype
cat_type3 = CategoricalDtype(categories=timez, ordered=True)

new_springdf['timezone'] = new_springdf['timezone'].astype(cat_type3)
new_summerdf['timezone'] = new_summerdf['timezone'].astype(cat_type3)
new_falldf['timezone'] = new_falldf['timezone'].astype(cat_type3)
new_winterdf['timezone'] = new_winterdf['timezone'].astype(cat_type3)

# %%
new_springdf.head()
# Out:
#   member_casual day_of_week time_of_day ride_length           ride_id  \
# 0        member      Monday         MID    00:06:17  47EC0A7F82E65D52
# 1        member   Wednesday          AM    00:06:18  8494861979B0F477
# 2        member   Wednesday          PM    00:02:46  EFE527AF80B66109
# 3        member     Tuesday          PM    00:09:48  9F446FD9DEE3F389
# 4        member      Monday          PM    00:42:10  431128AD9AFFEDC0
#
#      minutes  timezone
# 0   6.283333   0-15min
# 1   6.300000   0-15min
# 2   2.766667   0-15min
# 3   9.800000   0-15min
# 4  42.166667  30-45min

# %%
new_springdf4 = new_springdf[['member_casual','timezone','minutes']].copy()
new_summerdf4 = new_summerdf[['member_casual','timezone','minutes']].copy()
new_falldf4 = new_falldf[['member_casual','timezone','minutes']].copy()
new_winterdf4 = new_winterdf[['member_casual','timezone','minutes']].copy()

# %% [markdown]
# ### Comparison plot for total rides in different TIMEZONES for all 4 seasons

# %%
# Plot the seasons side by side to compare the total rides for different TIMEZONES

fig, axes = plt.subplots(2,2,sharey=True, figsize=(22, 16))
fig.suptitle('Total ride lengths for Spring, Summer, Fall, Winter: TIMEZONES', fontsize = 25)

# set titles
axes[0,0].set_title('Spring', fontsize = 18)
axes[0,1].set_title('Summer', fontsize = 18)
axes[1,0].set_title('Fall', fontsize = 18)
axes[1,1].set_title('Winter',fontsize = 18)

sns.barplot(ax=axes[0, 0], x='timezone', y = 'minutes', hue = 'member_casual', data = new_springdf4)
sns.barplot(ax=axes[0, 1], x='timezone', y = 'minutes', hue = 'member_casual', data = new_summerdf4)
sns.barplot(ax=axes[1, 0], x='timezone', y = 'minutes', hue = 'member_casual', data = new_falldf4)
sns.barplot(ax=axes[1, 1], x='timezone', y = 'minutes', hue = 'member_casual', data = new_winterdf4)

# %% [markdown]
# ### Observation
#
# As expected the total ride lengths for rides more than 45 minutes is very high for both the riders than any other duration.

# %% [markdown]
# # Analysis of casual and member rider behavior over 12 months

# %% [markdown]
# ### Find the TOTAL RIDES (MEMBER AND CASUAL RIDERS) OVER 12 MONTHS:
#
#     1. MONTHS
#     2. DAY OF WEEK
#     3. TIME OF DAY
#     4. TIME OF DAY AND DAY OF WEEK

# %% [markdown]
# ### 1. Find the total rides (members and casual) for the last 12 MONTHS: July 2021 - August 2022)

# %%
# create a new dataframe to find the total riders

total_df = pd.DataFrame(result['member_casual'].value_counts().reset_index().rename(columns = {'index':'member_casual','member_casual':'Total_riders'}))

# %%
total_df
# Out:
#   member_casual  Total_riders
# 0        member       3378379
# 1        casual       2521447

# %%
# get the percentage of total riders

total_df['riders_percent'] = round((total_df['Total_riders'] / total_df['Total_riders'].sum()) * 100, 2)
total_df
# Out:
#   member_casual  Total_riders  riders_percent
# 0        member       3378379           57.26
# 1        casual       2521447           42.74

# %% [markdown]
# ### Percentage of Casual and Member Riders for 12 month period

# %%
labels = ['Member Riders', 'Casual Riders']

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(total_df['riders_percent'], labels=labels,autopct='%1.0f%%')
ax.set_title('Percentage of Riders for 12 month period')
plt.tight_layout()

# %% [markdown]
# ### Observation
# From July 2021 to August 2022, there are 57% Member Riders and 43% Casual Riders

# %% [markdown]
# ### 2. Find TOTAL RIDES (Member and Casual)  over 12 months :DAY OF WEEK

# %%
# Order the days of the week in the right order: Monday, Tuesday, Wednesday....
cats = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
from pandas.api.types import CategoricalDtype
cat_type = CategoricalDtype(categories=cats, ordered=True)
result['day_of_week'] = result['day_of_week'].astype(cat_type)

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and memver riders
plotdata = result.groupby(['member_casual','day_of_week'], as_index = False)['ride_id'].count()

plotdata['riders_percent'] = round((plotdata['ride_id'] / plotdata['ride_id'].sum()) * 100, 2)

plotdata
# Out:
#    member_casual day_of_week  ride_id  riders_percent
# 0         casual      Monday   301191            5.11
# 1         casual     Tuesday   274011            4.64
# 2         casual   Wednesday   281652            4.77
# 3         casual    Thursday   315113            5.34
# 4         casual      Friday   345721            5.86
# 5         casual    Saturday   524868            8.90
# 6         casual      Sunday   478891            8.12
# 7         member      Monday   472482            8.01
# 8         member     Tuesday   523094            8.87
# 9         member   Wednesday   522308            8.85
# 10        member    Thursday   522274            8.85
# 11        member      Friday   465915            7.90
# 12        member    Saturday   452902            7.68
# 13        member      Sunday   419404            7.11

# %% [markdown]
# ### Total Rides for every day of the week over 12 months

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.barplot(x = 'day_of_week', y = 'ride_id', hue = 'member_casual', data = plotdata,
            palette = 'Blues', edgecolor = 'w')
plotdata.groupby(['day_of_week','member_casual']).count()
plt.title('Total Rides for every day of the week over 12 months', fontsize=18)
ax.set_xlabel("\n DAYS OF THE WEEK\n", fontsize=20)
ax.set_ylabel("\nTOTAL RIDES\n", fontsize=20)
plt.show()

# %% [markdown]
# ### Observation
# Member rides make up for most of the week: Monday to Friday. Casual rides make up for most of the weekends.

# %% [markdown]
# ### Percentage of total rides occuring on each day of the week:

# %%
# split data frame into two 
member_df, casual_df = [x for _, x in plotdata.groupby(plotdata['member_casual'] == 'casual')]

# %%
casual_df
# Out:
#   member_casual day_of_week  ride_id  riders_percent
# 0        casual      Monday   301191            5.11
# 1        casual     Tuesday   274011            4.64
# 2        casual   Wednesday   281652            4.77
# 3        casual    Thursday   315113            5.34
# 4        casual      Friday   345721            5.86
# 5        casual    Saturday   524868            8.90
# 6        casual      Sunday   478891            8.12

# %%
member_df
# Out:
#    member_casual day_of_week  ride_id  riders_percent
# 7         member      Monday   472482            8.01
# 8         member     Tuesday   523094            8.87
# 9         member   Wednesday   522308            8.85
# 10        member    Thursday   522274            8.85
# 11        member      Friday   465915            7.90
# 12        member    Saturday   452902            7.68
# 13        member      Sunday   419404            7.11

# %% [markdown]
# ### Percentage of Member Riders for 7 days of the week

# %%
# Plot a piechart showing percentage of member riders for 7 days of week

fig, ax = plt.subplots(figsize=(10, 8))
ax.pie(member_df['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Member Riders for 7 days of the week', fontsize = 20)
plt.legend(member_df['day_of_week'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Percentage of Casual Riders for 7 days of the week

# %%
# Plot a piechart showing percentage of casual riders for 7 days of week

fig, ax = plt.subplots(figsize=(10, 8))
ax.pie(casual_df['riders_percent'], autopct='%1.0f%%')
ax.set_title('Percentage of Casual Riders for 7 days of the week', fontsize = 20)
plt.legend(casual_df['day_of_week'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Observation
# Member riders are fairly consistent riders through the week, whereas Casual riders have increased numbers on saturday and sunday

# %% [markdown]
# ### 3a. Find the TOTAL RIDES over 12 months: TIME OF DAY

# %% [markdown]
#  We will now analyze the member rides and casual rides at different times of the day.
#
#  For the purpose of our analysis, we have defined the following time zones:
#
# “AM” - 4:00AM-9:59AM
#
# “MID” - 10:00AM-2:59PM
#
# “PM” - 3:00PM-7:59PM
#
# “LATE” - 8:00PM-3:59AM

# %%
# Count the rides in different times of the day
result.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  47EC0A7F82E65D52       Classic 2022-03-21 13:45:01 2022-03-21 13:51:18
# 1  8494861979B0F477      Electric 2022-03-16 09:37:16 2022-03-16 09:43:34
# 2  EFE527AF80B66109       Classic 2022-03-23 19:52:02 2022-03-23 19:54:48
# 3  9F446FD9DEE3F389       Classic 2022-03-01 19:12:26 2022-03-01 19:22:14
# 4  431128AD9AFFEDC0       Classic 2022-03-21 18:37:01 2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %%
# create a new dataframe to find the total riders for the 4 different time zones

time_df = pd.DataFrame(result['time_of_day'].value_counts().reset_index().rename(columns = {'index':'time_of_day','time_of_day':'Total_riders'}))

# %%
# Order the TIMES OF DAY in the right order: AM, MID, PM, Late
cats = [ 'AM', 'MID', 'PM', 'Late']
from pandas.api.types import CategoricalDtype
cat_type = CategoricalDtype(categories=cats, ordered=True)
result['time_of_day'] = result['time_of_day'].astype(cat_type)

# %%
time_df['Percentage'] = round(time_df['Total_riders']/ sum(time_df['Total_riders']) * 100, 2)
time_df
# Out:
#   time_of_day  Total_riders  Percentage
# 0          PM       2372405       40.21
# 1         MID       1626226       27.56
# 2        Late        991253       16.80
# 3          AM        909942       15.42

# %% [markdown]
# ### Total Rides for the different times of the day

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.barplot(x = 'time_of_day', y = 'Total_riders', data = time_df)
plt.title('Total Rides for the different times of the day', fontsize=18)
ax.set_xlabel("\n Times of the Day\n", fontsize=20)
ax.set_ylabel("\nTOTAL RIDES\n", fontsize=20)
plt.show()

# %% [markdown]
# ### Observation
# 1.The evening "PM" times (3:00PM-7:59PM) are the most busiest in terms of the total rides.
#
# 2. Whereas the morning"AM" times (4:00AM-9:59AM) are the least busiest in the entire day.

# %% [markdown]
# ### 3b. Find the TOTAL RIDES (member and casual riders)  over 12 months: TIME OF DAY

# %%
# Create a new dataframe for groupby the member_casual column and count the total rides for casual and memver riders for the different times of day
timedata = result.groupby(['member_casual','time_of_day'], as_index = False)['ride_id'].count()

timedata['riders_percent'] = round((timedata['ride_id'] / timedata['ride_id'].sum()) * 100, 2)

timedata
# Out:
#   member_casual time_of_day  ride_id  riders_percent
# 0        casual          AM   253057            4.29
# 1        casual         MID   743507           12.60
# 2        casual          PM  1014139           17.19
# 3        casual        Late   510744            8.66
# 4        member          AM   656885           11.13
# 5        member         MID   882719           14.96
# 6        member          PM  1358266           23.02
# 7        member        Late   480509            8.14

# %% [markdown]
# ### Total Rides for the different times of day over 12 months

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.barplot(x = 'time_of_day', y = 'ride_id', hue = 'member_casual', data = timedata,
            palette = 'Blues', edgecolor = 'w')
timedata.groupby(['time_of_day','member_casual']).count()
plt.title('Total Rides for the different times of day over 12 months', fontsize=18)
ax.set_xlabel("\n TIMES OF DAY\n", fontsize=20)
ax.set_ylabel("\nTOTAL RIDES\n", fontsize=20)
plt.show()

# %% [markdown]
# ### Observation:
# 1. The Evening (PM) times (3:00PM-7:59PM) are the times where the most member and casual rides occur.
# 2. The Morning (AM) times (4:00AM-9:59AM), the member riders are almost double the casual riders.
# 3. During the Late times (8:00PM-3:59AM), the casual riders are slighlty higher than the member riders.

# %% [markdown]
# ### Percentage rides by the time of day

# %%
# split data frame into two 
member_t, casual_t = [x for _, x in timedata.groupby(timedata['member_casual'] == 'casual')]

# %%
casual_t
# Out:
#   member_casual time_of_day  ride_id  riders_percent
# 0        casual          AM   253057            4.29
# 1        casual         MID   743507           12.60
# 2        casual          PM  1014139           17.19
# 3        casual        Late   510744            8.66

# %%
member_t
# Out:
#   member_casual time_of_day  ride_id  riders_percent
# 4        member          AM   656885           11.13
# 5        member         MID   882719           14.96
# 6        member          PM  1358266           23.02
# 7        member        Late   480509            8.14

# %% [markdown]
# ### Percentage of Member Riders by the time of day

# %%
# Plot a piechart showing percentage of member riders by the time of day

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(member_t['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Member Riders by the time of day', fontsize = 20)
plt.legend(member_t['time_of_day'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Percentage of Casual Riders by the time of day

# %%
# Plot a piechart showing percentage of casual riders by the time of day

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(casual_t['riders_percent'],autopct='%1.0f%%')
ax.set_title('Percentage of Casual Riders by the time of day', fontsize = 20)
plt.legend(casual_t['time_of_day'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Observations:
# 1. There is significant difference in the late time rides between member and casual riders. 14% to 20%
# 2. In the morning times, the percentage of member riders is significatly higher than casual riders. 19% to 10%
# 3. For the evening hours, the casual riders and member riders have the same percentage 40%

# %% [markdown]
# ### Next, we will analyze the data for both day of the week and time of the day together

# %% [markdown]
# ### 4.  TOTAL RIDES  (member and casual) ALL MONTHS:  TIME OF DAY AND DAY OF WEEK

# %%
# Creating new dataframe

new_df = result[['member_casual','day_of_week','time_of_day','ride_length']].copy()

# %%
new_df1 = result.groupby(['member_casual','day_of_week','time_of_day'], as_index = False)['ride_length'].count()

# %%
mon_df1 = new_df1[(new_df1['day_of_week'] == 'Monday')]
print (mon_df1)
# Out:
#    member_casual day_of_week time_of_day  ride_length
# 0         casual      Monday          AM        33431
# 1         casual      Monday         MID        86635
# 2         casual      Monday          PM       126669
# 3         casual      Monday        Late        54456
# 28        member      Monday          AM        99936
# 29        member      Monday         MID       110876
# 30        member      Monday          PM       204626
# 31        member      Monday        Late        57044

# %%
tue_df1 = new_df1[(new_df1['day_of_week'] == 'Tuesday')]
wed_df1 = new_df1[(new_df1['day_of_week'] == 'Wednesday')]
thu_df1 = new_df1[(new_df1['day_of_week'] == 'Thursday')]
fri_df1 = new_df1[(new_df1['day_of_week'] == 'Friday')]
sat_df1 = new_df1[(new_df1['day_of_week'] == 'Saturday')]
sun_df1 = new_df1[(new_df1['day_of_week'] == 'Sunday')]

# %% [markdown]
# ### Total rides for different times of the day and days of week'

# %%
fig, axes = plt.subplots(3,3,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Total rides for different times of the day and days of week', fontsize = 25)

# set titles
axes[0,0].set_title('Monday', fontsize = 18)
axes[0,1].set_title('Tuesday', fontsize = 18)
axes[0,2].set_title('Wednesday', fontsize = 18)
axes[1,0].set_title('Thursday', fontsize = 18)
axes[1,1].set_title('Friday',fontsize = 18)
axes[1,2].set_title('Saturday', fontsize = 18)
axes[2,0].set_title('Sunday', fontsize = 18)
   
# set data

ride_num = new_df[['member_casual', 'time_of_day', 'day_of_week', 'ride_length']].set_index('day_of_week')

Monday = ride_num.loc['Monday']
Tuesday = ride_num.loc['Tuesday']
Wednesday = ride_num.loc['Wednesday']
Thursday = ride_num.loc['Thursday']
Friday = ride_num.loc['Friday']
Saturday = ride_num.loc['Saturday']
Sunday = ride_num.loc['Sunday']


#sns.barplot(ax=axes[0,0], x=Monday.index, y=Monday.values)

sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = mon_df1)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = tue_df1)
sns.barplot(ax=axes[0, 2], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = wed_df1)
sns.barplot(ax=axes[1, 0], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = thu_df1)
sns.barplot(ax=axes[1, 1], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = fri_df1)
sns.barplot(ax=axes[1, 2], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = sat_df1)
sns.barplot(ax=axes[2, 0], x='time_of_day', y = 'ride_length', hue = 'member_casual', data = sun_df1)

# Delete the subplot [2,1] and [2,2] that are not needed
fig.delaxes(axes[2,1]) #The indexing is zero-based here
fig.delaxes(axes[2,2]) #The indexing is zero-based here

# %% [markdown]
# ### Observation: Behavioral differences between member and casaul riders depending on when the rides take place(time of day and during the week)
# The member riders are more than casual riders during the week days, Monday, Tuesday, Wednesday, Thursday . The evening hours see the highest frequency of member riders for weekdays.
# Whereas the casual riders are more than member riders during the weekends, saturday and sunday, peaking during the mid morning and evening hours.

# %% [markdown]
# ## Analyze the difference in riders behavior by looking at the RIDE LENGTH:
#
#     1. DAY OF WEEK
#     2. TIME OF DAY
#     3. DAY OF WEEK AND TIME OF DAY
#     4. TIMEZONES (DURATION OF RIDES)

# %% [markdown]
# ### 1. Find the TOTAL RIDE LENGTH for member and casual riders for all MONTHS: DAY OF WEEK
#
# To understand how the member riders and casual riders use Divvy Bikes, we analyze the total duration of the ride taken by the riders during the day of the week.

# %%
# Create a new dataframe for groupby the member_casual column and find the total RIDE_LENGTH for casual and member riders
ridedata1 = result.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].mean(numeric_only=False)

ridedata1
# Out:
#    member_casual day_of_week     ride_length
# 0         casual      Monday 00:33:53.161545
# 1         casual     Tuesday 00:28:03.113871
# 2         casual   Wednesday 00:28:03.286914
# 3         casual    Thursday 00:26:07.775464
# 4         casual      Friday 00:26:40.194399
# 5         casual    Saturday 00:28:37.608210
# 6         casual      Sunday 00:32:09.003950
# 7         member      Monday 00:12:35.422585
# 8         member     Tuesday 00:12:05.032613
# 9         member   Wednesday 00:12:15.289945
# 10        member    Thursday 00:12:19.700517
# 11        member      Friday 00:12:39.251125
# 12        member    Saturday 00:14:24.527520
# 13        member      Sunday 00:14:41.807035

# %%
# Create a new dataframe for groupby the member_casual column and find the total RIDE_LENGTH for casual and member riders
ridedata2 = result.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].count()

ridedata2
# Out:
#    member_casual day_of_week  ride_length
# 0         casual      Monday       301191
# 1         casual     Tuesday       274011
# 2         casual   Wednesday       281652
# 3         casual    Thursday       315113
# 4         casual      Friday       345721
# 5         casual    Saturday       524868
# 6         casual      Sunday       478891
# 7         member      Monday       472482
# 8         member     Tuesday       523094
# 9         member   Wednesday       522308
# 10        member    Thursday       522274
# 11        member      Friday       465915
# 12        member    Saturday       452902
# 13        member      Sunday       419404

# %%
# split data frame into two 
member_day, casual_day = [x for _, x in ridedata2.groupby(ridedata2['member_casual'] == 'casual')]

# %% [markdown]
# ### Find the Percentage of Casual and Member Riders for the days of the week during 12 month period

# %%
# Plot a piechart showing percentage of member riders by the time of day

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(casual_day['ride_length'],autopct='%1.0f%%')
ax.set_title('Percentage of Casual Riders for the days of the week during 12 month period', fontsize = 20)
plt.legend(casual_day['day_of_week'], loc="upper right")
plt.tight_layout()

# %%
# Plot a piechart showing percentage of member riders by the time of day

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(member_day['ride_length'],autopct='%1.0f%%')
ax.set_title('Percentage of Member Riders for the days of the week during 12 month period', fontsize = 20)
plt.legend(member_day['day_of_week'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Find the Average Ride lengths for member and casual rides for the days of the week over the 12 months

# %%
# to get the "total minutes":
ridedata1['mean_ride_minutes'] = ridedata1['ride_length'].dt.total_seconds()/60
ridedata1['mean_ride_minutes']
# Out:
# 0     33.886026
# 1     28.051898
# 2     28.054782
# 3     26.129591
# 4     26.669907
# 5     28.626804
# 6     32.150066
# 7     12.590376
# 8     12.083877
# 9     12.254832
# 10    12.328342
# 11    12.654185
# 12    14.408792
# 13    14.696784
# Name: mean_ride_minutes, dtype: float64

# %%
ridedata1
# Out:
#    member_casual day_of_week     ride_length  mean_ride_minutes
# 0         casual      Monday 00:33:53.161545          33.886026
# 1         casual     Tuesday 00:28:03.113871          28.051898
# 2         casual   Wednesday 00:28:03.286914          28.054782
# 3         casual    Thursday 00:26:07.775464          26.129591
# 4         casual      Friday 00:26:40.194399          26.669907
# 5         casual    Saturday 00:28:37.608210          28.626804
# 6         casual      Sunday 00:32:09.003950          32.150066
# 7         member      Monday 00:12:35.422585          12.590376
# 8         member     Tuesday 00:12:05.032613          12.083877
# 9         member   Wednesday 00:12:15.289945          12.254832
# 10        member    Thursday 00:12:19.700517          12.328342
# 11        member      Friday 00:12:39.251125          12.654185
# 12        member    Saturday 00:14:24.527520          14.408792
# 13        member      Sunday 00:14:41.807035          14.696784

# %%
# Create a new dataframe for groupby the member_casual column and find the total duration of rides for casual and memver riders
ridedata2 = result.groupby(['member_casual','day_of_week'], as_index = False)['ride_length'].median(numeric_only=False)
#ridedata['duration_percent'] = round((ridedata['ride_length'] / ridedata['ride_length'].sum()) * 100, 2)

ridedata2
# Out:
#    member_casual day_of_week ride_length
# 0         casual      Monday    00:14:32
# 1         casual     Tuesday    00:12:35
# 2         casual   Wednesday    00:12:34
# 3         casual    Thursday    00:12:48
# 4         casual      Friday    00:13:31
# 5         casual    Saturday    00:16:15
# 6         casual      Sunday    00:16:50
# 7         member      Monday    00:08:41
# 8         member     Tuesday    00:08:32
# 9         member   Wednesday    00:08:41
# 10        member    Thursday    00:08:45
# 11        member      Friday    00:08:50
# 12        member    Saturday    00:10:08
# 13        member      Sunday    00:10:04

# %%
# to get the "total minutes":
ridedata2['median_ride_minutes'] = ridedata2['ride_length'].dt.total_seconds()/60
ridedata2['median_ride_minutes']
# Out:
# 0     14.533333
# 1     12.583333
# 2     12.566667
# 3     12.800000
# 4     13.516667
# 5     16.250000
# 6     16.833333
# 7      8.683333
# 8      8.533333
# 9      8.683333
# 10     8.750000
# 11     8.833333
# 12    10.133333
# 13    10.066667
# Name: median_ride_minutes, dtype: float64

# %%
ridedata2
# Out:
#    member_casual day_of_week ride_length  median_ride_minutes
# 0         casual      Monday    00:14:32            14.533333
# 1         casual     Tuesday    00:12:35            12.583333
# 2         casual   Wednesday    00:12:34            12.566667
# 3         casual    Thursday    00:12:48            12.800000
# 4         casual      Friday    00:13:31            13.516667
# 5         casual    Saturday    00:16:15            16.250000
# 6         casual      Sunday    00:16:50            16.833333
# 7         member      Monday    00:08:41             8.683333
# 8         member     Tuesday    00:08:32             8.533333
# 9         member   Wednesday    00:08:41             8.683333
# 10        member    Thursday    00:08:45             8.750000
# 11        member      Friday    00:08:50             8.833333
# 12        member    Saturday    00:10:08            10.133333
# 13        member      Sunday    00:10:04            10.066667

# %% [markdown]
# ### Average Ride lengths by day of the week

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.barplot(x = 'day_of_week', y = 'mean_ride_minutes', hue = 'member_casual', data = ridedata1)
ridedata1.groupby(['day_of_week','member_casual']).count()
plt.title('Average Ride lengths for the days of the week over the 12 months', fontsize=18)
ax.set_xlabel("\n DAYS OF THE WEEK\n", fontsize=20)
ax.set_ylabel("\nAVERAGE RIDE LENGTHS\n", fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Observation:
#  The average member rides are fairly consistent throughout the week, with slight rise on the weekends.
#  Where as the average casual rides are much higher than member rides throughout the week and peaking on the weekends.
#  We need to further analyze this observation.

# %% [markdown]
# ### Find the median ride length for casual and member rides by day of the week

# %%
fig, ax = plt.subplots(figsize=(12, 7))
ax = sns.barplot(x = 'day_of_week', y = 'median_ride_minutes', hue = 'member_casual', data = ridedata2)
ridedata2.groupby(['day_of_week','member_casual']).count()
plt.title('Median Ride lengths for the days of the week over the 12 months', fontsize=18)
ax.set_xlabel("\n DAYS OF THE WEEK\n", fontsize=20)
ax.set_ylabel("\nMEDIAN RIDE LENGTH\n", fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Plotting the mean and median side by side for the days of the week

# %%
fig, axes = plt.subplots(2,2,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Comparison of Median and Mean for the ride lengths for each day of the week', fontsize = 25)

# set titles
axes[0,0].set_title('MEAN RIDE LENGTH', fontsize = 18)
axes[0,1].set_title('MEDIAN RIDE LENGTH', fontsize = 18)

sns.barplot(ax=axes[0, 0], x='day_of_week', y = 'mean_ride_minutes', hue = 'member_casual', data = ridedata1)
sns.barplot(ax=axes[0, 1], x='day_of_week', y = 'median_ride_minutes', hue = 'member_casual', data = ridedata2)

# Delete the subplot [1,0] and [1,1] that are not needed
fig.delaxes(axes[1,0]) #The indexing is zero-based here
fig.delaxes(axes[1,1]) #The indexing is zero-based here

# %% [markdown]
# ### Observation:
# As seen at the side by side comparison of mean and median ride lengths. The difference is quite significant.
#
# The mean ride length has very high ride lengths for casaul riders maybe because of outliers having significantly high ride lengths. And the casual ride lengths are almost double those of the member ride lengths.
#
# As seen in the median rides plot, there is not a big difference between the ride lengths of casual riders and member riders.

# %% [markdown]
# ### 2. Analyze the difference in riders behavior by looking at the RIDE LENGTH: for TIME OF DAY

# %%
# Mean
# Create a new dataframe for groupby the member_casual column and find the total duration of rides for casual and memver riders
timedata1 = result.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only=False)

timedata1
# Out:
#   member_casual time_of_day     ride_length
# 0        casual          AM 00:24:03.559134
# 1        casual         MID 00:31:39.306350
# 2        casual          PM 00:28:29.869706
# 3        casual        Late 00:29:39.197386
# 4        member          AM 00:11:44.461226
# 5        member         MID 00:12:52.824137
# 6        member          PM 00:13:28.453494
# 7        member        Late 00:13:08.024001

# %%
# to get the "total minutes":
timedata1['mean_ride_minutes'] = timedata1['ride_length'].dt.total_seconds()/60
timedata1['mean_ride_minutes']
# Out:
# 0    24.059319
# 1    31.655106
# 2    28.497828
# 3    29.653290
# 4    11.741020
# 5    12.880402
# 6    13.474225
# 7    13.133733
# Name: mean_ride_minutes, dtype: float64

# %%
# Median
# Create a new dataframe for groupby the member_casual column and find the total duration of rides for casual and memver riders
timedata2 = result.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
#ridedata['duration_percent'] = round((ridedata['ride_length'] / ridedata['ride_length'].sum()) * 100, 2)

timedata2
# Out:
#   member_casual time_of_day ride_length
# 0        casual          AM    00:11:10
# 1        casual         MID    00:16:37
# 2        casual          PM    00:14:50
# 3        casual        Late    00:12:52
# 4        member          AM    00:08:28
# 5        member         MID    00:08:38
# 6        member          PM    00:09:33
# 7        member        Late    00:09:03

# %%
# to get the "median minutes":
timedata2['median_ride_minutes'] = timedata2['ride_length'].dt.total_seconds()/60
timedata2['median_ride_minutes']
# Out:
# 0    11.166667
# 1    16.616667
# 2    14.833333
# 3    12.866667
# 4     8.466667
# 5     8.633333
# 6     9.550000
# 7     9.050000
# Name: median_ride_minutes, dtype: float64

# %% [markdown]
# ### Comparison of Median and Mean for the ride lengths for Times of Day

# %%
fig, axes = plt.subplots(1,2,sharex=True,sharey=True, figsize=(15, 5))
fig.suptitle('Comparison of Median and Mean for the ride lengths for Times of Day', fontsize = 18)

# set titles
axes[0].set_title('MEAN RIDE LENGTH', fontsize = 12)
axes[1].set_title('MEDIAN RIDE LENGTH', fontsize = 12)

sns.barplot(ax=axes[0], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = timedata1)
sns.barplot(ax=axes[1], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = timedata2)

# %% [markdown]
# ### Observation
# The member rides remain fairly consistent when looking at the mean and median ride lengths for the times of the day.
#
# The casual riders on the other hand show a different trend: the mean ride length is highest at MID morning, followed by Late evening.
# But median casual ride length is highest for MID morning, followed by PM evening time as second highest and NOT late evening.
# There appears to be some outliers in the Late evening data for casual riders.

# %% [markdown]
# ### 3. Analyze the behavior differences with RIDE LENGTH: DAY OF WEEK AND TIME OF DAY

# %% [markdown]
# ### Find the mean ride lengths for Times of Day and Days of week

# %%
new_df5 = result[['member_casual','day_of_week','time_of_day','ride_length']].copy()

# %%
new_df5 = result.groupby(['member_casual','day_of_week','time_of_day'], as_index = False)['ride_length'].mean(numeric_only =False)

# %%
new_df5.head()
# Out:
#   member_casual day_of_week time_of_day     ride_length
# 0        casual      Monday          AM 00:25:07.187371
# 1        casual      Monday         MID 00:36:29.945564
# 2        casual      Monday          PM 00:32:01.639896
# 3        casual      Monday        Late 00:39:26.039371
# 4        casual     Tuesday          AM 00:19:15.881878

# %%
mon_df5 = new_df5[(new_df5['day_of_week'] == 'Monday')]
tue_df5 = new_df5[(new_df5['day_of_week'] == 'Tuesday')]
wed_df5 = new_df5[(new_df5['day_of_week'] == 'Wednesday')]
thu_df5 = new_df5[(new_df5['day_of_week'] == 'Thursday')]
fri_df5 = new_df5[(new_df5['day_of_week'] == 'Friday')]
sat_df5 = new_df5[(new_df5['day_of_week'] == 'Saturday')]
sun_df5 = new_df5[(new_df5['day_of_week'] == 'Sunday')]

# %%
mon_df5.head()
# Out:
#    member_casual day_of_week time_of_day     ride_length
# 0         casual      Monday          AM 00:25:07.187371
# 1         casual      Monday         MID 00:36:29.945564
# 2         casual      Monday          PM 00:32:01.639896
# 3         casual      Monday        Late 00:39:26.039371
# 28        member      Monday          AM 00:11:34.091058

# %%
# Mean
# Create a new dataframe for groupby the member_casual column and find the mean of ride lengths for casual and memver riders
mon_df2 = mon_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)
tue_df2 = tue_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)
wed_df2 = wed_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)
thu_df2 = thu_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)
fri_df2 = fri_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)
sat_df2 = sat_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)
sun_df2 = sun_df5.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].mean(numeric_only = False)

# %%
# to get the "total minutes":
mon_df2['mean_ride_minutes'] = mon_df2['ride_length'].dt.total_seconds()/60
tue_df2['mean_ride_minutes'] = tue_df2['ride_length'].dt.total_seconds()/60
wed_df2['mean_ride_minutes'] = wed_df2['ride_length'].dt.total_seconds()/60
thu_df2['mean_ride_minutes'] = thu_df2['ride_length'].dt.total_seconds()/60
fri_df2['mean_ride_minutes'] = fri_df2['ride_length'].dt.total_seconds()/60
sat_df2['mean_ride_minutes'] = sat_df2['ride_length'].dt.total_seconds()/60
sun_df2['mean_ride_minutes'] = sun_df2['ride_length'].dt.total_seconds()/60

# %%
mon_df2
# Out:
#   member_casual time_of_day     ride_length  mean_ride_minutes
# 0        casual          AM 00:25:07.187371          25.119790
# 1        casual         MID 00:36:29.945564          36.499093
# 2        casual          PM 00:32:01.639896          32.027332
# 3        casual        Late 00:39:26.039371          39.433990
# 4        member          AM 00:11:34.091058          11.568184
# 5        member         MID 00:12:32.805458          12.546758
# 6        member          PM 00:13:00.899045          13.014984
# 7        member        Late 00:12:56.568683          12.942811

# %% [markdown]
# ### Comparison of Mean ride lengths for Times of Day and Days of week

# %%
fig, axes = plt.subplots(3,3,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('Average ride length for different times of the day and days of week', fontsize = 25)

# set titles
axes[0,0].set_title('Monday', fontsize = 18)
axes[0,1].set_title('Tuesday', fontsize = 18)
axes[0,2].set_title('Wednesday', fontsize = 18)
axes[1,0].set_title('Thursday', fontsize = 18)
axes[1,1].set_title('Friday',fontsize = 18)
axes[1,2].set_title('Saturday', fontsize = 18)
axes[2,0].set_title('Sunday', fontsize = 18)
   
# set data

ride_num = new_df[['member_casual', 'time_of_day', 'day_of_week', 'ride_length']].set_index('day_of_week')

Monday = ride_num.loc['Monday']
Tuesday = ride_num.loc['Tuesday']
Wednesday = ride_num.loc['Wednesday']
Thursday = ride_num.loc['Thursday']
Friday = ride_num.loc['Friday']
Saturday = ride_num.loc['Saturday']
Sunday = ride_num.loc['Sunday']


#sns.barplot(ax=axes[0,0], x=Monday.index, y=Monday.values)

sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = mon_df2)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = tue_df2)
sns.barplot(ax=axes[0, 2], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = wed_df2)
sns.barplot(ax=axes[1, 0], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = thu_df2)
sns.barplot(ax=axes[1, 1], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = fri_df2)
sns.barplot(ax=axes[1, 2], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = sat_df2)
sns.barplot(ax=axes[2, 0], x='time_of_day', y = 'mean_ride_minutes', hue = 'member_casual', data = sun_df2)

# Delete the subplot [2,1] and [2,2] that are not needed
fig.delaxes(axes[2,1]) #The indexing is zero-based here
fig.delaxes(axes[2,2]) #The indexing is zero-based here

# %% [markdown]
# ### Observation
# The average member rides are highest on PM hours for the weekdays,
# whereas the casual ride lengths are maximum over the weekends during the MID anf PM hours.

# %% [markdown]
# ### Find the median ride lengths for Times of Day and Days of week

# %%
new_df6 = result[['member_casual','day_of_week','time_of_day','ride_length']].copy()

# %%
new_df6 = result.groupby(['member_casual','day_of_week','time_of_day'], as_index = False)['ride_length'].median(numeric_only =False)

# %%
new_df6.head()
# Out:
#   member_casual day_of_week time_of_day ride_length
# 0        casual      Monday          AM    00:10:51
# 1        casual      Monday         MID    00:17:09
# 2        casual      Monday          PM    00:14:48
# 3        casual      Monday        Late    00:13:19
# 4        casual     Tuesday          AM    00:09:56

# %%
mon_df6 = new_df6[(new_df5['day_of_week'] == 'Monday')]
tue_df6 = new_df6[(new_df5['day_of_week'] == 'Tuesday')]
wed_df6 = new_df6[(new_df5['day_of_week'] == 'Wednesday')]
thu_df6 = new_df6[(new_df5['day_of_week'] == 'Thursday')]
fri_df6 = new_df6[(new_df5['day_of_week'] == 'Friday')]
sat_df6 = new_df6[(new_df5['day_of_week'] == 'Saturday')]
sun_df6 = new_df6[(new_df5['day_of_week'] == 'Sunday')]

# %%
# Median
# Create a new dataframe for groupby the member_casual column and find the median of ride length for casual and memver riders
mon_df3 = mon_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
tue_df3 = tue_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
wed_df3 = wed_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
thu_df3 = thu_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
fri_df3 = fri_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
sat_df3 = sat_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)
sun_df3 = sun_df6.groupby(['member_casual','time_of_day'], as_index = False)['ride_length'].median(numeric_only=False)

# %%
# to get the "total minutes":
mon_df3['median_ride_minutes'] = mon_df3['ride_length'].dt.total_seconds()/60
tue_df3['median_ride_minutes'] = tue_df3['ride_length'].dt.total_seconds()/60
wed_df3['median_ride_minutes'] = wed_df3['ride_length'].dt.total_seconds()/60
thu_df3['median_ride_minutes'] = thu_df3['ride_length'].dt.total_seconds()/60
fri_df3['median_ride_minutes'] = fri_df3['ride_length'].dt.total_seconds()/60
sat_df3['median_ride_minutes'] = sat_df3['ride_length'].dt.total_seconds()/60
sun_df3['median_ride_minutes'] = sun_df3['ride_length'].dt.total_seconds()/60

# %% [markdown]
# ### Comparison of Median ride lengths for different times of the day and days of week'

# %%
fig, axes = plt.subplots(3,3,sharex=True,sharey=True, figsize=(22, 16))
fig.suptitle('The Median ride lengths for different times of the day and days of week', fontsize = 25)

# set titles
axes[0,0].set_title('Monday', fontsize = 18)
axes[0,1].set_title('Tuesday', fontsize = 18)
axes[0,2].set_title('Wednesday', fontsize = 18)
axes[1,0].set_title('Thursday', fontsize = 18)
axes[1,1].set_title('Friday',fontsize = 18)
axes[1,2].set_title('Saturday', fontsize = 18)
axes[2,0].set_title('Sunday', fontsize = 18)
   
# set data

ride_num = new_df[['member_casual', 'time_of_day', 'day_of_week', 'ride_length']].set_index('day_of_week')

Monday = ride_num.loc['Monday']
Tuesday = ride_num.loc['Tuesday']
Wednesday = ride_num.loc['Wednesday']
Thursday = ride_num.loc['Thursday']
Friday = ride_num.loc['Friday']
Saturday = ride_num.loc['Saturday']
Sunday = ride_num.loc['Sunday']


#sns.barplot(ax=axes[0,0], x=Monday.index, y=Monday.values)

sns.barplot(ax=axes[0, 0], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = mon_df3)
sns.barplot(ax=axes[0, 1], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = tue_df3)
sns.barplot(ax=axes[0, 2], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = wed_df3)
sns.barplot(ax=axes[1, 0], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = thu_df3)
sns.barplot(ax=axes[1, 1], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = fri_df3)
sns.barplot(ax=axes[1, 2], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = sat_df3)
sns.barplot(ax=axes[2, 0], x='time_of_day', y = 'median_ride_minutes', hue = 'member_casual', data = sun_df3)

# Delete the subplot [2,1] and [2,2] that are not needed
fig.delaxes(axes[2,1]) #The indexing is zero-based here
fig.delaxes(axes[2,2]) #The indexing is zero-based here

# %% [markdown]
# ### Observation
# The median plots show that the median ride lengths for member riders are fairly consistent through the day for weekdays.
# For casual riders show an increase on MID and PM hours on Saturday and Sunday.

# %% [markdown]
# ### 4. Analyze the casual and member rider RIDE LENGTH based on the duration of their rides (TIMEZONES)

# %% [markdown]
# #### Create a new Category called Duration with the following classification:
# 0-15 minutes
#
# 15-30 minutes
#
# 30-45 minutes
#
# 45+ minutes

# %%
result.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  47EC0A7F82E65D52       Classic 2022-03-21 13:45:01 2022-03-21 13:51:18
# 1  8494861979B0F477      Electric 2022-03-16 09:37:16 2022-03-16 09:43:34
# 2  EFE527AF80B66109       Classic 2022-03-23 19:52:02 2022-03-23 19:54:48
# 3  9F446FD9DEE3F389       Classic 2022-03-01 19:12:26 2022-03-01 19:22:14
# 4  431128AD9AFFEDC0       Classic 2022-03-21 18:37:01 2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %%
new_df7 = result[['member_casual','rideable_type','day_of_week','time_of_day','ride_length','ride_id']].copy()

# %%
new_df7.head()
# Out:
#   member_casual rideable_type day_of_week time_of_day ride_length  \
# 0        member       Classic      Monday         MID    00:06:17
# 1        member      Electric   Wednesday          AM    00:06:18
# 2        member       Classic   Wednesday          PM    00:02:46
# 3        member       Classic     Tuesday          PM    00:09:48
# 4        member       Classic      Monday          PM    00:42:10
#
#             ride_id
# 0  47EC0A7F82E65D52
# 1  8494861979B0F477
# 2  EFE527AF80B66109
# 3  9F446FD9DEE3F389
# 4  431128AD9AFFEDC0

# %%
new_df7['minutes'] = new_df7['ride_length'].dt.total_seconds()/60

new_df7.head()
# Out:
#   member_casual rideable_type day_of_week time_of_day ride_length  \
# 0        member       Classic      Monday         MID    00:06:17
# 1        member      Electric   Wednesday          AM    00:06:18
# 2        member       Classic   Wednesday          PM    00:02:46
# 3        member       Classic     Tuesday          PM    00:09:48
# 4        member       Classic      Monday          PM    00:42:10
#
#             ride_id    minutes
# 0  47EC0A7F82E65D52   6.283333
# 1  8494861979B0F477   6.300000
# 2  EFE527AF80B66109   2.766667
# 3  9F446FD9DEE3F389   9.800000
# 4  431128AD9AFFEDC0  42.166667

# %%
new_df7['timezone'] = np.where((new_df7['minutes'] >= 0) & (new_df7['minutes'] <=15), '0-15min',
                      np.where((new_df7['minutes'] >15) & (new_df7['minutes'] <= 30 ), '15-30min',
                      np.where((new_df7['minutes'] >30) & (new_df7['minutes'] <= 45), '30-45min', '+45min')))

# %%
new_df7.head(30)
# Out:
#    member_casual rideable_type day_of_week time_of_day ride_length  \
# 0         member       Classic      Monday         MID    00:06:17
# 1         member      Electric   Wednesday          AM    00:06:18
# 2         member       Classic   Wednesday          PM    00:02:46
# 3         member       Classic     Tuesday          PM    00:09:48
# 4         member       Classic      Monday          PM    00:42:10
# 5         member       Classic      Monday          PM    00:04:42
# 6         member      Electric    Thursday          PM    00:03:17
# 7         member       Classic    Saturday         MID    00:11:17
# 8         casual      Electric    Thursday          PM    00:10:43
# 9         member       Classic      Friday          PM    00:13:14
# 10        casual       Classic      Sunday        Late    00:18:16
# 11        member       Classic   Wednesday          AM    00:04:53
# 12        member      Electric      Monday          PM    00:04:29
# ...

# %%
new_df8 = new_df7[['member_casual','timezone', 'ride_id']].copy()

# %%
new_df8 = new_df8.groupby(['member_casual','timezone'], as_index = False).count()

# %% [markdown]
# ### Total rides (members and casual ) for different TIMEZONES

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.barplot(x = 'timezone', y = 'ride_id', hue = 'member_casual', data = new_df8)
new_df7.groupby(['member_casual', 'timezone']).count()
plt.title('Total Rides for different timezones', fontsize=18)
ax.set_xlabel("\n TIMEZONES\n", fontsize=20)
ax.set_ylabel("\nTOTAL RIDES\n", fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Observation
# The number of member rides under 15 minutes is far greater than the number of casual rides under 15 minutes.
# The number of casual rides is greater for all more 30 min cateogries.

# %% [markdown]
# ### Percentage of rides that fall into each timezone

# %%
# split data frame into two 
member_d, casual_d = [x for _, x in new_df8.groupby(new_df8['member_casual'] == 'casual')]

# %%
member_d
# Out:
#   member_casual  timezone  ride_id
# 4        member    +45min    57606
# 5        member   0-15min  2477070
# 6        member  15-30min   673470
# 7        member  30-45min   170233

# %%
# Plot a piechart showing percentage member rides for different Timezones

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(member_d['ride_id'],autopct='%1.0f%%')
ax.set_title('Percentage of Member Rides for different timezones', fontsize = 20)
plt.legend(member_d['timezone'], loc="upper right")
plt.tight_layout()

# %%
casual_d
# Out:
#   member_casual  timezone  ride_id
# 0        casual    +45min   285114
# 1        casual   0-15min  1308691
# 2        casual  15-30min   690417
# 3        casual  30-45min   237225

# %%
# Plot a piechart showing percentage of Casual rides for different Timezones

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(casual_d['ride_id'],autopct='%1.0f%%')
ax.set_title('Percentage of Casual Rides for different timezones', fontsize = 20)
plt.legend(casual_d['timezone'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### Observation
# #### Member riders:
#
# 73% of members account for rides lasting to less than or equal to 15 minutes.
#
# Only 2% of members have ride duration of more than 45 minutes.
#
# #### Casual riders:
#
# 52% of casual riders account for rides lasting to less than oe equal to 15 minutes.
#
# About 11% account for ride duration more than 45 minutes, with lowest percentage is 9% for rides lasting  between 30 to 45 minutes.

# %% [markdown]
# ## Analysis of behavior of casual and member riders with different types of Bikes(Classic , Electric)
#
# ### Find the types of bikes used in last 12 months .
#
#     1. TOTAL of bike types
#     2. TOTAL BIKE TYPES (member and casual riders)
#     3. DAYS OF WEEK
#     4. TIMES OF DAY
#     5. TIMEZONES(DURATION OF RIDES)

# %% [markdown]
# ### 1. Find the total of different types of bikes used during the last 12 months

# %%
result.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  47EC0A7F82E65D52       Classic 2022-03-21 13:45:01 2022-03-21 13:51:18
# 1  8494861979B0F477      Electric 2022-03-16 09:37:16 2022-03-16 09:43:34
# 2  EFE527AF80B66109       Classic 2022-03-23 19:52:02 2022-03-23 19:54:48
# 3  9F446FD9DEE3F389       Classic 2022-03-01 19:12:26 2022-03-01 19:22:14
# 4  431128AD9AFFEDC0       Classic 2022-03-21 18:37:01 2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %%
# create a new dataframe to find the total bike types

biketype_df = pd.DataFrame(result['rideable_type'].value_counts().reset_index().rename(columns = {'index':'rideable_type','rideable_type':'Total_biketype'}))

# %%
biketype_df.head()
# Out:
#   rideable_type  Total_biketype
# 0       Classic         3054895
# 1      Electric         2618251
# 2        Docked          226680

# %%
biketype_df['percent'] = round((biketype_df['Total_biketype'] / biketype_df['Total_biketype'].sum()) * 100, 2)
biketype_df.head()
# Out:
#   rideable_type  Total_biketype  percent
# 0       Classic         3054895    51.78
# 1      Electric         2618251    44.38
# 2        Docked          226680     3.84

# %%
# Plot a piechart showing percentage of bike types 

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(biketype_df['Total_biketype'],autopct='%1.0f%%')
ax.set_title('Percentage of Bike types', fontsize = 20)
plt.legend(biketype_df['rideable_type'], loc="upper right")
plt.tight_layout()

# %% [markdown]
# ### 2. Analysis of different Bike types for casual and member riders annually.

# %%
biketype_df1 = result[['member_casual','rideable_type', 'ride_id']].copy()

# %%
biketype_df1 = biketype_df1.groupby(['member_casual','rideable_type'], as_index = False).count()

# %%
#Remove rows with rideable type "Docked", since these bikes are docked at stations waiting to be used.

# %%
biketype_df1.drop(biketype_df1.loc[biketype_df1['rideable_type']== 'Docked'].index, inplace=True)

# %% [markdown]
# #### Total count of different types of bikes for casual and member riders

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.barplot(x = 'rideable_type', y = 'ride_id', hue = 'member_casual', data = biketype_df1)
result.groupby(['member_casual', 'rideable_type']).count()
plt.title('Total count of different types of bikes for casual and member riders', fontsize=18)
ax.set_xlabel("\n BIKE TYPES\n", fontsize=20)
ax.set_ylabel("\nTOTAL COUNT \n", fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Observation
#
# Member Riders use the Classic bikes more than Casual riders
#
# In comaprison, casual riders have about the same use of electric and classic bikes.

# %% [markdown]
# ### 3. Find the types of bikes used: DAYS OF WEEK

# %% [markdown]
# We get to know the behavior pattern for casual & member riders in regards to their preference for type of bike, during the week for times of the day.

# %%
biketype_df2 = result[['member_casual','rideable_type','day_of_week','ride_id']].copy()
biketype_df2.head()
# Out:
#   member_casual rideable_type day_of_week           ride_id
# 0        member       Classic      Monday  47EC0A7F82E65D52
# 1        member      Electric   Wednesday  8494861979B0F477
# 2        member       Classic   Wednesday  EFE527AF80B66109
# 3        member       Classic     Tuesday  9F446FD9DEE3F389
# 4        member       Classic      Monday  431128AD9AFFEDC0

# %%
monbike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Monday')]
tuebike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Tuesday')]
wedbike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Wednesday')]
thubike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Thursday')]
fribike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Friday')]
satbike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Saturday')]
sunbike_df2 = biketype_df2[(biketype_df2['day_of_week'] == 'Sunday')]

# %%
monbike_df2.head()
# Out:
#    member_casual rideable_type day_of_week           ride_id
# 0         member       Classic      Monday  47EC0A7F82E65D52
# 4         member       Classic      Monday  431128AD9AFFEDC0
# 5         member       Classic      Monday  9AA8A13AF7A85325
# 12        member      Electric      Monday  F1A67F55CB0F9A98
# 13        member      Electric      Monday  62DF2EB49628DC9A

# %%
# Create a new dataframe for groupby the member_casual column 
monbike_df3 = monbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
tuebike_df3 = tuebike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
wedbike_df3 = wedbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
thubike_df3 = thubike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
fribike_df3 = fribike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
satbike_df3 = satbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
sunbike_df3 = sunbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()

# %%
#monbike_df3

# %%
fig, axes = plt.subplots(3,3,sharey=True,figsize=(22, 16))
fig.suptitle('The total bike types days of week', fontsize = 25)

# set titles
axes[0,0].set_title('Monday', fontsize = 18)
axes[0,1].set_title('Tuesday', fontsize = 18)
axes[0,2].set_title('Wednesday', fontsize = 18)
axes[1,0].set_title('Thursday', fontsize = 18)
axes[1,1].set_title('Friday',fontsize = 18)
axes[1,2].set_title('Saturday', fontsize = 18)
axes[2,0].set_title('Sunday', fontsize = 18)
   
# set data

bikeride_num = biketype_df2[['member_casual', 'rideable_type', 'day_of_week']].set_index('day_of_week')

Monday = bikeride_num.loc['Monday']
Tuesday = bikeride_num.loc['Tuesday']
Wednesday = bikeride_num.loc['Wednesday']
Thursday = bikeride_num.loc['Thursday']
Friday = bikeride_num.loc['Friday']
Saturday = bikeride_num.loc['Saturday']
Sunday = bikeride_num.loc['Sunday']


fig.text(0.5, 0.04,'Types of Bikes Available to be used', ha='center', fontsize = 25)
fig.text(0.04, 0.5, 'Count of Bikes used', va='center', rotation='vertical', fontsize = 25)

sns.barplot(ax=axes[0, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = monbike_df3)
sns.barplot(ax=axes[0, 1], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = tuebike_df3)
sns.barplot(ax=axes[0, 2], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = wedbike_df3)
sns.barplot(ax=axes[1, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = thubike_df3)
sns.barplot(ax=axes[1, 1], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = fribike_df3)
sns.barplot(ax=axes[1, 2], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = satbike_df3)
sns.barplot(ax=axes[2, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = sunbike_df3)

# Delete the subplot [2,1] and [2,2] that are not needed
fig.delaxes(axes[2,1]) #The indexing is zero-based here
fig.delaxes(axes[2,2]) #The indexing is zero-based here

# %% [markdown]
# ### Obersvation
#
# Casual riders :
#
#     The total rides on electric bikes are higher during the weekends when compared to rides taken by member riders on electric bike.
#
#     The total rides on classic bikes are higher than total rides on electric bikes during weekends.
#
#     On weekdays, total rides on classic and electric bikes are almost the same count.
#
#
# Member riders:
#
#     The total rides on Classic bikes is higher than electric bikes for all days of the week.

# %% [markdown]
# ### 4. Find the types of bikes used: TIMES OF DAY

# %% [markdown]
# we can find out if the times of the day affects the preference of bike types.

# %%
biketype_df3 = result[['member_casual','rideable_type','time_of_day','ride_id']].copy()
biketype_df3.head()
# Out:
#   member_casual rideable_type time_of_day           ride_id
# 0        member       Classic         MID  47EC0A7F82E65D52
# 1        member      Electric          AM  8494861979B0F477
# 2        member       Classic          PM  EFE527AF80B66109
# 3        member       Classic          PM  9F446FD9DEE3F389
# 4        member       Classic          PM  431128AD9AFFEDC0

# %%
AMbike_df2 = biketype_df3[(biketype_df3['time_of_day'] == 'AM')]
MIDbike_df2 = biketype_df3[(biketype_df3['time_of_day'] == 'MID')]
PMbike_df2 = biketype_df3[(biketype_df3['time_of_day'] == 'PM')]
Latebike_df2 = biketype_df3[(biketype_df3['time_of_day'] == 'Late')]

# %%
# Create a new dataframe for groupby the member_casual column 
AMbike_df3 = AMbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
MIDbike_df3 = MIDbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
PMbike_df3 = PMbike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
Latebike_df3 = Latebike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()

# %%
fig, axes = plt.subplots(2,2,sharey=True,figsize=(22, 16))
fig.suptitle('The total bike types for times of the day', fontsize = 25)

# set titles
axes[0,0].set_title('AM', fontsize = 18)
axes[0,1].set_title('MID', fontsize = 18)
axes[1,0].set_title('PM', fontsize = 18)
axes[1,1].set_title('Late', fontsize = 18)

# set data

timeride_num = biketype_df3[['member_casual', 'rideable_type', 'time_of_day']].set_index('time_of_day')

AM = timeride_num.loc['AM']
MID = timeride_num.loc['MID']
PM = timeride_num.loc['PM']
Late = timeride_num.loc['Late']


fig.text(0.5, 0.04,'Types of Bikes Available to be used', ha='center', fontsize = 25)
fig.text(0.04, 0.5, 'Count of Bikes used', va='center', rotation='vertical', fontsize = 25)

sns.barplot(ax=axes[0, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = AMbike_df3)
sns.barplot(ax=axes[0, 1], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = MIDbike_df3)
sns.barplot(ax=axes[1, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = PMbike_df3)
sns.barplot(ax=axes[1, 1], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = Latebike_df3)

# Delete the subplot [2,1] and [2,2] that are not needed
#fig.delaxes(axes[2,1]) #The indexing is zero-based here
#fig.delaxes(axes[2,2]) #The indexing is zero-based here

# %% [markdown]
# ### Observation
#
# Casual Riders:
#
#         The total rides are relatively same for both classic and electric bikes.
#         Maximum no.of bikes used during the PM hours.
#         Least no.of bikes used during the AM hours.
#
# Member Riders:
#
#         The classic bikes usage is more than electric bikes for all times of the day.
#         Maximum rides are during the PM hours, with total bike rides with classic bikes higher than rides with
#         electric bikes.
#         Least rides are during the Late hours.

# %% [markdown]
# ### 5. Find the types of bikes used: TIMEZONES

# %% [markdown]
# we find out if the durations of bike rides affects the type of bike used.

# %%
biketype_df4 = new_df7[['member_casual','rideable_type','timezone','ride_id']].copy()
biketype_df4.head()
# Out:
#   member_casual rideable_type  timezone           ride_id
# 0        member       Classic   0-15min  47EC0A7F82E65D52
# 1        member      Electric   0-15min  8494861979B0F477
# 2        member       Classic   0-15min  EFE527AF80B66109
# 3        member       Classic   0-15min  9F446FD9DEE3F389
# 4        member       Classic  30-45min  431128AD9AFFEDC0

# %%
zone1bike_df2 = biketype_df4[(biketype_df4['timezone'] == '0-15min')]
zone2bike_df2 = biketype_df4[(biketype_df4['timezone'] == '15-30min')]
zone3bike_df2 = biketype_df4[(biketype_df4['timezone'] == '30-45min')]
zone4bike_df2 = biketype_df4[(biketype_df4['timezone'] == '+45min')]

# %%
# Create a new dataframe for groupby the member_casual column 
zone1bike_df3 = zone1bike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
zone2bike_df3 = zone2bike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
zone3bike_df3 = zone3bike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()
zone4bike_df3 = zone4bike_df2.groupby(['member_casual','rideable_type'], as_index = False)['ride_id'].count()

# %%
fig, axes = plt.subplots(2,2,sharey=True,figsize=(22, 16))
fig.suptitle('The total bike types for different durations', fontsize = 25)

# set titles
axes[0,0].set_title('0-15min', fontsize = 18)
axes[0,1].set_title('15-30min', fontsize = 18)
axes[1,0].set_title('30-45min', fontsize = 18)
axes[1,1].set_title('+45min', fontsize = 18)

# set data

zoneride_num = biketype_df4[['member_casual', 'rideable_type', 'timezone']].set_index('timezone')

Less_than_15min = zoneride_num.loc['0-15min']
Bet_15_and_30min = zoneride_num.loc['15-30min']
Bet_30_and_45min = zoneride_num.loc['30-45min']
More_than_45min = zoneride_num.loc['+45min']


fig.text(0.5, 0.04,'Types of Bikes Available to be used', ha='center', fontsize = 25)
fig.text(0.04, 0.5, 'Count of Bikes used', va='center', rotation='vertical', fontsize = 25)

sns.barplot(ax=axes[0, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = zone1bike_df3)
sns.barplot(ax=axes[0, 1], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = zone2bike_df3)
sns.barplot(ax=axes[1, 0], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = zone3bike_df3)
sns.barplot(ax=axes[1, 1], x='rideable_type', y = 'ride_id', hue = 'member_casual', data = zone4bike_df3)

# %% [markdown]
# ### Observation
#
# How does the duration of rides affect the type of bike used by casual and member riders?
#
# 1. 0-15 minute rides: Maximum rides are in this duration for both casual and member riders.
#
#     Classic bikes used by members far exceed the Electric bikes used by members.
#     The casual riders usage of the electric bike is more than the classic bikes.
#
# 2. 45+ minute rides: Least rides are in this duration for both casual and member riders.
#
#     The casual riders have more rides than member riders.
#     The casual rides use the classic bikes slighly higher than electric bikes.

# %% [markdown]
# ## OBSERVATIONS:
#
# ### How do members and casual riders differ in their use of Divvy Bikes?
#
# #### Anlayzing the rider behavior over the 12 month period:
# The following observations and trends are seen:
#
# 1. MORNING HOURS:
#
# 19% of member rides start between 4AM-10AM
# Only 10% of casual rides start between 4AM-10AM
#
# CONCLUSION: MORNING TIME BELONGS TO THE MEMBER RIDERS
#
# 2. LATE HOURS:
#
# 20% of casual rideS start between 8PM-4AM
# Only 14% of member rides start between 8PM-4AM
#
# CONCLUSION: LATE HOURS BELONG TO CASUAL RIDERS
#
# 3. WEEKENDS:
#
# 41% of casual rides occur on the weekends.
# Only 25% of member rides occur on the weekends.
#
# CONCLUSION: WEEKENDS BELONG TO CASUAL RIDERS.
#
# 4. DURATION OF RIDES(member riders):
#
# 73% of member rides are less than 15 minutes long.
# whereas 52% of casual rides are less than 15 minutes long.
#
# CONCLUSION: MEMBER RIDES ARE SHORTER THAN CASUAL RIDES.
#
# 5. DURATION OF RIDES(casual riders):
#
# 36% of casual rides last longer than 15 minutes
# Only 25% of member rides last longer than 15 minutes
#
# CONCLUSION: CASUAL RIDES ARE LONGER THAN MEMBER RIDES.
#
#
# #### Anlayzing the rider behavior over the 4 seasons: Spring, Summer, Fall, Winter
# The following observations and trends are seen:
#
#     Overall total number of rides are highest during the summer season, followed by fall and spring. Winter months see a overall decrease in the total rides.
#
# SUMMER season:
#
# 1. Morning (AM) hours:
#     18% OF MEMBER rides are in the AM hours and only 9% of CASUAL rides.
#     0-15minute rides for MEMBER are greater than for CASUAL.
# 2. Late hours:
#     Casual rides (22%) are more than member rides (16%) in the Late hours.
# 3. 69% of MEMBER rides are of duration less than 15 minutes. And 51% of CASUAL rides are of duration less than 15   minutes.
# 4. The rides of duration more than 45min are less for MEMBERS compared to CASUAL.
# 5. 73% MEMBER rides are during the course of weekdays, and only 60% are CASUAL rides.
# 6. On weekends, MEMBER rides are 28% as compared to 40% CASUAL rides.
# 7. On weekdays, the MEMBER ride durations less than 15min are greater than CASUAL ride durations of less than 15 min
# 8. MEMBER ride durations of less than 15 min are lower than CASUAL ride durations less than 15 min.
# 9. 45+ min rides for CASUAL riders are greater than MEMBER riders.
# 10. CASUAL rides of more than 30 minutes are more than MEMBER rides.
#
#
# FALL season:
#
# 1. Morning (AM) hours:
#     20% OF MEMBER rides are in the AM hours and only 11% of CASUAL rides.
#     LOWEST total rides are in AM with less than 15 minute duration.
# 2. Late hours:
#     Casual rides (19%) are more than member rides (14%) in the Late hours.
# 3. 74% of MEMBER rides are of duration less than 15 minutes. And 53% of CASUAL rides are of duration less than 15   minutes.
# 4. The rides of duration more than 45min are less for MEMBERS(2%) compared to CASUAL(11%).
# 5. 74% MEMBER rides are during the course of weekdays, and only 59% are CASUAL rides.
# 6. On weekends, MEMBER rides are 26% as compared to 41% CASUAL rides.
# 7. On weekdays, MEMBER ride durations less than 15min are greater than CASUAL ride durations of less than 15 min
# 8. On weekends, MEMBER ride durations of less than 15 min are lower than CASUAL ride durations less than 15 min.
# 9. 45+ min rides for CASUAL riders are greater than MEMBER riders.
# 10. CASUAL rides of greater than 30 minutes are highest in Mid and PM hours.
#
# WIINTER Season:
# 1. Morning (AM) hours:
#     29% OF MEMBER rides are in the AM hours and only 12% of CASUAL rides.
#     AM hours has lowest CASUAL rides.
# 2. Late hours:
#     Casual rides (18%) are more than member rides (11%) in the Late hours.
#     LATE HOURS has Lowest total member rides
#
# 3. 80% of MEMBER and CASUAl rides are of duration less than 15 minutes. But Total MEMBER rides are more than CASUAL rides
# 4. The rides of duration more than 45min are less for MEMBERS(1%) compared to CASUAL(6%).
# 5. 79% MEMBER rides are during the course of weekdays, and only 69% are CASUAL rides.
# 6. On weekends, MEMBER rides are 21% as compared to 30% CASUAL rides.
# 7. On weekdays, MEMBER ride durations less than 15min are greater than CASUAL ride durations of less than 15 min
# 8. On weekends, MEMBER ride durations of less than 15 min are lower than CASUAL ride durations less than 15 min.
# 9. PM hours: The total MEMBER rides of duration less than 15 minutes is higher than total CASUAL rides
#
#
# CONCLUSIONS:
# 1. Member riders are influenced by the workday. They most likely Divvy bikes to travel to and from work, which would account for the greater ride count between 4AM-10AM and consistent ride length across the week.
#
# 2. Casual riders use Divvy bikes more frequently after 10AM and on the weekends, likely for leisure activities. This is corroborated by higher ride count and longer ride length on Saturdays and Sundays.
#
# 3. SPRING and FALL season the total rides increase for both riders.
#
# The CASUAL rides are LESS in the AM hours and More in PM hours.
# 0-15min rides for CASUAL rides are 51% which is highest. And 22% of CASUAL rides are of duration more than 30  minutes.
# About 40% of CASUAL rides take place on the weekends.
# The Total CASUAL rides of more than 45 minute are higher than total MEMBER rides of more than 45 minutes.
#
# TYPE OF BIKES (CLASSIC AND ELECTRIC)
#
# 1. The classic bikes(54%) are used more than the electric bikes(44%).
# 2. Generally Member riders use both kinds of bikes more than Casual riders.
# 3. Casual riders use of classsic bikes and Elctric bikes is the same.
# 4. Member riders use of Classic bikes is more than Electric bikes.
# 5. Casual riders slightly prefer the Electric bikes during the Weekdays, and prefer classic bikes more on the Weekdays.
# 6. Casual riders use of electric bikes are more than Member riders use of electric bikes during weekends.
# 7. The Classic bike use by both the riders remains the same over the weekends.
# 8. In the Morning hours, Member riders use the Classic bike more than electric bike.
# 9. The Casual riders use Classic/Electric bikes less often than members during the AM hours.
# 10. In PM hours, use of electric bikes by Casual Riders is almost equal to Member riders.
# 11. In the Late hours, both riders use of classic and electric bikes is almost same.
# 12. For durations of less than 15 minutes, Members prefer Classic bikes over Electric bikes.
# 13. There a lot more member riders riding the Classic bikes than Casual riders for less than 15 minutes duration.
# 14. For longer durations of more than 45 minutes, Casual riders prefer electric bike more than member riders.

# %% [markdown]
# ### SUMMARY OF CASUAL RIDER BEHAVIOR:
#
#  There is an increase in the CASUAL riders during SUMMER And FALL season.
#
#  The casual riders are active later in the Day, and the duration of most of their rides are within 15 minutes.
#
#  Most of the CASUAL Rides take place in the WEEKENDS.
#
#  The Casual riders also take longer rides of more than 45 minutes during Summer and Winter.
#
#  Late hours belong to CASUAL riders.
#
#  Casual riders slightly prefer the Electric bikes during the Weekdays, and prefer classic bikes more on the Weekdays.
#
#  For longer durations of more than 45 minutes, Casual riders prefer electric bike more than member riders.

# %% [markdown]
# ### What can help to convert the Casual riders get Annual membership and become Member riders?
#
# To approach a campaign that aims at Casual riders, it will be helpful to focus on developing incentives around weekends, evening/late night hours, longer rides, classic/electric bikes, especially during the Summer and Fall months.
#
# Current Annual membership plans include the following benefits as of August 2022:
#
# 1. You can take as many rides as you want throughout the year
# 2. The first 45 minutes of each ride are included in your plan.
# 3. If you keep a bike out for more than 45 minutes at a time, it’s an extra $0.15/min.
#
# Current Single ride pass as of August 2022:
# 1. The Single Ride is just $3.30 and
#
# 2. It includes 30 minutes of ride time.
#
# 3. If you keep a bike out for more than 30 minutes, It's an extra $0.15/minute.
#
# Current Day pass as of August 2022:
# 1. The Day Pass costs $15 and
#
# 2. Includes unlimited rides in a 24-hour period, up to 3 hours each
#
# 3. For ride longer than 3 hours: You can either check your bike in and check another bike out to avoid usage fees, or  it's just an extra $0.15 per minute to keep the same bike out for longer than 3 hours.
#
#
#
# ### The following changes to membership benefits may convert casual riders:
#
# 1. Increase the ride length limit for the unlimited rides benefit.
# 2. Earn additional membeship points for rides on the weekends
# 3. Earn additional membership points for rides between 8PM-4AM
# 4. The membership points can be used towards upgrading to Electric bikes, or towards gaining more free ride minutes.
#
# Also, can look into the possiblilty of starting a new Annual membership juat for Casual Riders.
# 1. This can specifically focus on Casual riders, who are more seasonal riders.
# 2. develop incentives during the summer and fall months, like discounted membership fees, discount on Late hour rides.
# 3. Weekend ride points to attract more riders, to get discounted extra minutes to be used any time.
# 4. Access to discounted rates for Electric Bikes during the summer and fall months.
#
#
# Future analysis will focus on zoning of the electric bikes.
#
# This concludes the analysis of behavioral differences between member and casual rides from July 2021- August 2022
